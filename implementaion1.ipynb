# %%
# Corrected Implementation of "Constrained Diffusion Models for Synthesizing Representative Power Flow Datasets"
# Based on Hoseinpour & Dvorkin (2024)

# 1. Installs
# !pip install torch torchvision torchaudio --quiet
# !pip install pandapower tqdm matplotlib scipy numpy pandas seaborn --quiet

# 2. Imports and Setup
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandapower as pp
import pandapower.networks as pn
import math
import os
import copy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.optimize import linear_sum_assignment

# 3. Configuration
CONFIG = {
    "system": "case30",
    "num_samples": 3000,  # Increased for better training
    "num_synthetic_samples": 50,  # Number of samples to generate for comparison
    "diffusion_steps": 1000,  # Matched to paper
    "beta_start": 1e-4,
    "beta_end": 0.02,
    "hidden_dim": 256,
    "depth": 5,
    "batch_size": 64,
    "epochs": 100,  # Increased for better convergence
    "lr": 1e-4,
    "lambda_guidance": 0.01,  # Adjusted to paper's range (10^-4 to 10^-2)
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "seed": 42,
}

# 4. Model and Utility Definitions
class SinusoidalTimeEmbedding(nn.Module):
    """Sinusoidal positional encoding for time steps"""
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, t):
        device = t.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = t[:, None] * emb[None, :]
        return torch.cat((torch.sin(emb), torch.cos(emb)), dim=-1)

class DenoiserMLP(nn.Module):
    """Denoiser neural network ε_θ as described in the paper"""
    def __init__(self, dim_in, hidden=256, depth=3, time_embed_dim=128):
        super().__init__()
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)

        layers = []
        for i in range(depth):
            in_dim = dim_in + time_embed_dim if i == 0 else hidden
            out_dim = hidden if i < depth - 1 else dim_in
            layers.append(nn.Linear(in_dim, out_dim))
            if i < depth - 1:
                layers.append(nn.SiLU())  # Using SiLU (Swish) activation
                layers.append(nn.LayerNorm(out_dim))

        self.net = nn.Sequential(*layers)

        # Initialize weights
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_normal_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x, t):
        t_emb = self.time_embed(t.float())
        h = torch.cat([x, t_emb], dim=-1)
        return self.net(h)

class MinMaxNorm:
    """Min-max normalization to [-1, 1] range as per Section V-B of the paper"""
    def __init__(self, xmin, xmax, eps=1e-8):
        self.xmin = xmin.clone().detach() if isinstance(xmin, torch.Tensor) else torch.tensor(xmin, dtype=torch.float32)
        self.xmax = xmax.clone().detach() if isinstance(xmax, torch.Tensor) else torch.tensor(xmax, dtype=torch.float32)
        self.eps = eps
        self.range = torch.clamp(self.xmax - self.xmin, min=eps)

    def norm(self, x):
        """Normalize to [-1, 1] using equation (30)"""
        return 2 * (x - self.xmin.to(x.device)) / self.range.to(x.device) - 1

    def denorm(self, x):
        """Denormalize using equation (31)"""
        return ((x + 1) / 2) * self.range.to(x.device) + self.xmin.to(x.device)

    def scale_gradient(self, grad):
        """Scale gradient according to equation (32)"""
        return grad * 2 / self.range.to(grad.device)

def make_beta_schedule(T, beta_start=1e-4, beta_end=0.02, schedule='linear'):
    """Create noise schedule as described in Section III-A"""
    if schedule == 'linear':
        betas = torch.linspace(beta_start, beta_end, T)
    elif schedule == 'cosine':
        # Alternative cosine schedule
        s = 0.008
        steps = T + 1
        x = torch.linspace(0, T, steps)
        alphas_cumprod = torch.cos(((x / T) + s) / (1 + s) * torch.pi * 0.5) ** 2
        alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
        betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
        betas = torch.clip(betas, beta_start, beta_end)

    alphas = 1.0 - betas
    alpha_bar = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bar

def power_flow_residual(x_phys, G, B):
    """
    Compute power flow residual based on Equations (8a) and (8b) from the paper.
    This is the correct formulation using power balance equations.
    """
    Bdim = G.shape[0]
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    batch_size = x_phys.shape[0]
    device = x_phys.device

    # Ensure G and B are tensors on the correct device
    if not isinstance(G, torch.Tensor):
        G = torch.tensor(G, dtype=torch.float32, device=device)
    if not isinstance(B, torch.Tensor):
        B = torch.tensor(B, dtype=torch.float32, device=device)

    # Expand dimensions for broadcasting
    v_i = v.unsqueeze(2)  # [batch, Bdim, 1]
    v_j = v.unsqueeze(1)  # [batch, 1, Bdim]
    theta_i = theta.unsqueeze(2)  # [batch, Bdim, 1]
    theta_j = theta.unsqueeze(1)  # [batch, 1, Bdim]

    # Calculate angle differences
    theta_diff = theta_i - theta_j  # [batch, Bdim, Bdim]

    # Power flow equations from the paper
    # P_i = Σ_j v_i * v_j * (G_ij * cos(θ_i - θ_j) + B_ij * sin(θ_i - θ_j))
    P_calc = torch.sum(v_i * v_j * (G * torch.cos(theta_diff) + B * torch.sin(theta_diff)), dim=2)

    # Q_i = Σ_j v_i * v_j * (G_ij * sin(θ_i - θ_j) - B_ij * cos(θ_i - θ_j))
    Q_calc = torch.sum(v_i * v_j * (G * torch.sin(theta_diff) - B * torch.cos(theta_diff)), dim=2)

    # Residuals (power balance mismatch)
    p_residual = p - P_calc
    q_residual = q - Q_calc

    return torch.cat([p_residual, q_residual], dim=-1)

def compute_inequality_violations(x_phys, net):
    """Compute violations of inequality constraints (10a-10d)"""
    Bdim = len(net.bus)
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    violations = []

    # Voltage limits (10c)
    v_min = torch.tensor(net.bus.min_vm_pu.values, device=x_phys.device)
    v_max = torch.tensor(net.bus.max_vm_pu.values, device=x_phys.device)
    violations.append(torch.relu(v_min - v))  # v >= v_min
    violations.append(torch.relu(v - v_max))  # v <= v_max

    return torch.cat(violations, dim=-1)

def make_dataset(net_fn, N=500, scale_range=(0.8, 1.0), seed=0):
    """Generate ground truth dataset by solving AC-OPF as described in Section VI-A"""
    np.random.seed(seed)
    torch.manual_seed(seed)

    net = net_fn()
    base_loads_p = net.load["p_mw"].copy()
    base_loads_q = net.load["q_mvar"].copy()

    samples = []
    print(f"Generating {N} samples...")

    pbar = tqdm(range(N), desc="Generating Data")
    for _ in pbar:
        net_temp = copy.deepcopy(net)

        # Sample load scaling factors uniformly as in the paper
        scale_p = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))
        scale_q = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))

        net_temp.load["p_mw"] = base_loads_p * scale_p
        net_temp.load["q_mvar"] = base_loads_q * scale_q

        try:
            # Run power flow (not OPF for simplicity in this implementation)
            pp.runpp(net_temp, algorithm='nr', init='dc', numba=False, max_iteration=50)

            if net_temp.converged:
                # Extract power injections and voltages
                p = net_temp.res_bus.p_mw.values
                q = net_temp.res_bus.q_mvar.values
                v = net_temp.res_bus.vm_pu.values
                theta = np.deg2rad(net_temp.res_bus.va_degree.values)

                # Stack into single vector
                sample = np.concatenate([p, q, v, theta])
                samples.append(sample)
                pbar.set_postfix({"collected": len(samples)})

        except Exception as e:
            continue

    print(f"Successfully generated {len(samples)} samples.")
    return torch.tensor(np.array(samples), dtype=torch.float32)

def train_model(data, B, config):
    """Train diffusion model with variable decoupling (Algorithm 4)"""
    device = config["device"]
    T = config["diffusion_steps"]

    # Create noise schedule
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Initialize denoiser networks for variable decoupling
    den1 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)

    # Normalization
    data_min = data.min(0).values
    data_max = data.max(0).values

    # Add small noise to constant columns
    data_range = data_max - data_min
    constant_mask = data_range < 1e-6
    if constant_mask.any():
        print(f"Warning: Found {constant_mask.sum().item()} constant columns. Adding small noise.")
        data_min[constant_mask] -= 1e-4
        data_max[constant_mask] += 1e-4

    normer = MinMaxNorm(data_min, data_max)
    data_norm = normer.norm(data)

    # Check for NaN/Inf
    if torch.isnan(data_norm).any() or torch.isinf(data_norm).any():
        print("ERROR: NaN or Inf detected after normalization!")
        return None, None, None, None

    # Create dataloader
    loader = DataLoader(TensorDataset(data_norm), batch_size=config["batch_size"], shuffle=True)

    # Optimizer
    opt = torch.optim.AdamW(
        list(den1.parameters()) + list(den2.parameters()),
        lr=config["lr"],
        weight_decay=1e-5
    )

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=config["epochs"])

    loss_history = []

    print("Starting training...")
    for ep in range(config["epochs"]):
        total_loss = 0
        num_batches = 0

        pbar = tqdm(loader, desc=f"Epoch {ep+1}/{config['epochs']}")

        for (xb,) in pbar:
            xb = xb.to(device)

            # Variable decoupling: split into (p,θ) and (q,v)
            x1 = torch.cat([xb[:, :B], xb[:, 3*B:4*B]], dim=-1)  # (p, θ)
            x2 = torch.cat([xb[:, B:2*B], xb[:, 2*B:3*B]], dim=-1)  # (q, v)

            # Sample random timesteps
            t = torch.randint(0, T, (xb.size(0),), device=device)

            # Sample noise
            eps1 = torch.randn_like(x1)
            eps2 = torch.randn_like(x2)

            # Forward diffusion (equation 3)
            sqrt_ab_t = torch.sqrt(alpha_bar[t]).unsqueeze(-1)
            sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t]).unsqueeze(-1)

            x1_t = sqrt_ab_t * x1 + sqrt_1_minus_ab_t * eps1
            x2_t = sqrt_ab_t * x2 + sqrt_1_minus_ab_t * eps2

            # Predict noise
            pred1 = den1(x1_t, t)
            pred2 = den2(x2_t, t)

            # MSE loss (equation 5)
            loss1 = ((eps1 - pred1)**2).mean()
            loss2 = ((eps2 - pred2)**2).mean()
            loss = loss1 + loss2

            # Check for NaN
            if torch.isnan(loss):
                print(f"\nNaN loss detected at epoch {ep+1}!")
                break

            opt.zero_grad()
            loss.backward()

            # Gradient clipping for stability
            torch.nn.utils.clip_grad_norm_(
                list(den1.parameters()) + list(den2.parameters()),
                max_norm=1.0
            )

            opt.step()

            total_loss += loss.item()
            num_batches += 1
            pbar.set_postfix(loss=f"{loss.item():.4f}")

        scheduler.step()

        avg_loss = total_loss / num_batches
        loss_history.append(avg_loss)
        print(f"Epoch {ep+1} - Average Loss: {avg_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}")

    # Save checkpoint
    checkpoint = {
        "den1": den1.state_dict(),
        "den2": den2.state_dict(),
        "xmin": normer.xmin,
        "xmax": normer.xmax,
        "range": normer.range,
        "B": B
    }
    torch.save(checkpoint, "checkpoint.pth")
    print("Model saved to checkpoint.pth")

    return den1, den2, normer, loss_history

def sample_with_guidance(G, Bmat, config, ckpt_path="checkpoint.pth", track_residuals=False):
    """Sampling with manifold-constrained gradient guidance (Algorithm 5)"""
    device = config["device"]

    # Load checkpoint
    ckpt = torch.load(ckpt_path, map_location=device)
    Bdim = ckpt["B"]

    # Initialize denoisers
    den1 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den1.load_state_dict(ckpt["den1"])
    den2.load_state_dict(ckpt["den2"])
    den1.eval()
    den2.eval()

    # Normalizer
    normer = MinMaxNorm(ckpt["xmin"], ckpt["xmax"])
    if "range" in ckpt:
        normer.range = ckpt["range"]

    # Noise schedule
    T = config["diffusion_steps"]
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Guidance strength
    lam = config["lambda_guidance"]

    # Initialize from pure noise
    x_t = torch.randn(1, 4 * Bdim, device=device)

    # Track residuals if requested
    residual_history = [] if track_residuals else None

    print("Starting guided sampling..." if track_residuals else "Sampling...")
    pbar = tqdm(reversed(range(T)), desc="Sampling", total=T, disable=not track_residuals)

    for t in pbar:
        # Split for variable decoupling
        x1_t = torch.cat([x_t[:, :Bdim], x_t[:, 3*Bdim:4*Bdim]], dim=-1)  # (p, θ)
        x2_t = torch.cat([x_t[:, Bdim:2*Bdim], x_t[:, 2*Bdim:3*Bdim]], dim=-1)  # (q, v)

        with torch.no_grad():
            t_tensor = torch.tensor([t], device=device)

            # Predict noise (denoisers)
            eps1 = den1(x1_t, t_tensor)
            eps2 = den2(x2_t, t_tensor)

        # Estimate clean data using Tweedie's formula (equation 6)
        sqrt_ab_t = torch.sqrt(alpha_bar[t])
        sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t])

        hat_x0_p1 = (x1_t - sqrt_1_minus_ab_t * eps1) / (sqrt_ab_t + 1e-8)
        hat_x0_p2 = (x2_t - sqrt_1_minus_ab_t * eps2) / (sqrt_ab_t + 1e-8)

        # Reconstruct full vector
        hat_x0_norm = torch.zeros(1, 4*Bdim, device=device)
        hat_x0_norm[:, :Bdim] = hat_x0_p1[:, :Bdim]  # p
        hat_x0_norm[:, Bdim:2*Bdim] = hat_x0_p2[:, :Bdim]  # q
        hat_x0_norm[:, 2*Bdim:3*Bdim] = hat_x0_p2[:, Bdim:2*Bdim]  # v
        hat_x0_norm[:, 3*Bdim:4*Bdim] = hat_x0_p1[:, Bdim:2*Bdim]  # θ

        # Clamp for stability
        hat_x0_norm = torch.clamp(hat_x0_norm, -3, 3)

        # Apply gradient guidance if lambda > 0
        if lam > 0 and t > 0:  # No guidance at t=0
            hat_x0_norm.requires_grad_(True)

            # Denormalize for physics evaluation
            x_phys = normer.denorm(hat_x0_norm)

            # Compute power flow residual
            residual = power_flow_residual(x_phys, G, Bmat)
            residual_loss = (residual**2).sum()

            if track_residuals:
                residual_history.append(torch.sqrt(residual_loss).item())

            if not torch.isnan(residual_loss):
                # Compute gradient with respect to normalized variables
                grad_norm = torch.autograd.grad(residual_loss, hat_x0_norm, create_graph=False)[0]

                # Scale gradient properly
                grad_norm = normer.scale_gradient(grad_norm)

                # Clip gradient for stability
                grad_norm = torch.clamp(grad_norm, -1.0, 1.0)

                # Apply guidance (equation 23)
                guidance_strength = lam * (1 - t/T)  # Decay guidance over time
                hat_x0_guided = hat_x0_norm - guidance_strength * grad_norm
                hat_x0_guided = hat_x0_guided.detach()
            else:
                hat_x0_guided = hat_x0_norm.detach()
        else:
            hat_x0_guided = hat_x0_norm.detach()

        # Split guided estimate for variable decoupling
        hat_x0_guided_p1 = torch.cat([hat_x0_guided[:, :Bdim], hat_x0_guided[:, 3*Bdim:4*Bdim]], dim=-1)
        hat_x0_guided_p2 = torch.cat([hat_x0_guided[:, Bdim:2*Bdim], hat_x0_guided[:, 2*Bdim:3*Bdim]], dim=-1)

        # Reverse diffusion step (equation 7)
        if t > 0:
            z = torch.randn_like(x_t)
            z1 = torch.cat([z[:, :Bdim], z[:, 3*Bdim:4*Bdim]], dim=-1)
            z2 = torch.cat([z[:, Bdim:2*Bdim], z[:, 2*Bdim:3*Bdim]], dim=-1)
        else:
            z1 = z2 = 0

        beta_t = betas[t]
        alpha_t = alphas[t]
        alpha_bar_prev = alpha_bar[t-1] if t > 0 else torch.tensor(1.0, device=device)

        # DDPM sampling coefficients
        coef1 = torch.sqrt(alpha_bar_prev) * beta_t / (1 - alpha_bar[t] + 1e-8)
        coef2 = torch.sqrt(alpha_t) * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8)
        sigma_t = torch.sqrt(beta_t * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8))

        # Update x1_t and x2_t
        x1_t = coef1 * hat_x0_guided_p1 + coef2 * x1_t + sigma_t * z1
        x2_t = coef1 * hat_x0_guided_p2 + coef2 * x2_t + sigma_t * z2

        # Reconstruct full x_t
        x_t[:, :Bdim] = x1_t[:, :Bdim]
        x_t[:, Bdim:2*Bdim] = x2_t[:, :Bdim]
        x_t[:, 2*Bdim:3*Bdim] = x2_t[:, Bdim:2*Bdim]
        x_t[:, 3*Bdim:4*Bdim] = x1_t[:, Bdim:2*Bdim]

    # Final denormalization
    final_sample = normer.denorm(x_t).cpu().numpy()

    if track_residuals:
        return final_sample, residual_history
    return final_sample

def compute_wasserstein_distances(data1, data2):
    """Compute 1D Wasserstein distances for each variable group (P, Q, V, θ)"""
    dim = data1.shape[1]
    B = dim // 4
    groups = {
        'P': slice(0, B),
        'Q': slice(B, 2*B),
        'V': slice(2*B, 3*B),
        'theta': slice(3*B, 4*B)
    }
    distances = {}
    for name, sl in groups.items():
        d1 = data1[:, sl].flatten()
        d2 = data2[:, sl].flatten()
        d1_sorted = np.sort(d1)
        d2_sorted = np.sort(d2)
        distances[name] = np.mean(np.abs(d1_sorted - d2_sorted))
    avg_distance = np.mean(list(distances.values()))
    return distances, avg_distance

# 5. Main Execution with Verification
if __name__ == "__main__":
    torch.manual_seed(CONFIG['seed'])
    np.random.seed(CONFIG['seed'])

    # Load network
    network_function = getattr(pn, CONFIG['system'])
    net = network_function()
    num_buses = len(net.bus)
    print(f"Using {CONFIG['system']} with {num_buses} buses")

    # Get admittance matrix
    pp.runpp(net)
    Ybus = net._ppc['internal']['Ybus']
    G_matrix, B_matrix = Ybus.real.toarray(), Ybus.imag.toarray()

    # Generate ground truth dataset
    dataset = make_dataset(network_function, N=CONFIG['num_samples'], seed=CONFIG['seed'])

    if len(dataset) > 0:
        print(f"\nDataset shape: {dataset.shape}")
        print(f"Dataset stats:")
        print(f"  P range: [{dataset[:, :num_buses].min():.2f}, {dataset[:, :num_buses].max():.2f}] MW")
        print(f"  Q range: [{dataset[:, num_buses:2*num_buses].min():.2f}, {dataset[:, num_buses:2*num_buses].max():.2f}] MVAr")
        print(f"  V range: [{dataset[:, 2*num_buses:3*num_buses].min():.3f}, {dataset[:, 2*num_buses:3*num_buses].max():.3f}] p.u.")
        print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")

        # Check ground truth feasibility
        print("\nChecking ground truth feasibility...")
        gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
        gt_residuals = power_flow_residual(gt_tensor, G_matrix, B_matrix)
        gt_mismatch = torch.sqrt((gt_residuals**2).mean(dim=1))
        print(f"Ground truth power mismatch (first 10): {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

        # Train the diffusion model
        den1, den2, normer, loss_history = train_model(dataset, num_buses, CONFIG)

        if den1 is not None:
            # Generate synthetic samples
            print(f"\nGenerating {CONFIG['num_synthetic_samples']} synthetic samples...")
            synthetic_samples = []

            # First sample with residual tracking
            first_sample, residual_history = sample_with_guidance(
                G_matrix, B_matrix, CONFIG, track_residuals=True
            )
            synthetic_samples.append(first_sample[0])

            # Generate remaining samples
            for i in tqdm(range(1, CONFIG['num_synthetic_samples']), desc="Generating samples"):
                sample = sample_with_guidance(G_matrix, B_matrix, CONFIG, track_residuals=False)
                synthetic_samples.append(sample[0])

            synthetic_data = np.array(synthetic_samples)
            ground_truth_data = dataset.numpy()

            # Verification Results
            print("\n" + "="*60)
            print("VERIFICATION RESULTS (As per Table I and II in the paper)")
            print("="*60)

            # 1. Wasserstein Distance (Table I)
            print("\n1. Statistical Similarity (Wasserstein Distance):")
            subset_size = min(1000, len(ground_truth_data), len(synthetic_data))
            distances, avg_w_distance = compute_wasserstein_distances(
                ground_truth_data[:subset_size],
                synthetic_data[:subset_size]
            )
            for name, dist in distances.items():
                print(f"   {name} Wasserstein distance: {dist:.4f}")
            print(f"   Average Wasserstein distance: {avg_w_distance:.4f}")

            # ==============================================================
            # 2. Constraint Satisfaction (Section VI-C)
            # ==============================================================
            print("\n2. Constraint Satisfaction (Power Flow Residuals):")
            synth_tensor = torch.tensor(synthetic_data, dtype=torch.float32)
            synth_residuals = power_flow_residual(synth_tensor, G_matrix, B_matrix)
            synth_mismatch = torch.sqrt((synth_residuals ** 2).mean(dim=1))
            print(f"   Synthetic mean mismatch: {synth_mismatch.mean():.6f} ± {synth_mismatch.std():.6f}")
            print(f"   Ground truth mean mismatch: {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

            # Plot residual convergence history
            plt.figure(figsize=(6, 4))
            plt.plot(residual_history, linewidth=2)
            plt.xlabel("Diffusion step (t)")
            plt.ylabel("Residual norm ||H(x)||₂")
            plt.title("Residual Convergence During Guided Sampling")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 3. Visual Comparison (Section VI-B figures)
            # ==============================================================
            print("\n3. Visualizing statistical similarity...")

            var_names = ['P (MW)', 'Q (MVAr)', 'V (p.u.)', 'θ (rad)']
            num_buses = G_matrix.shape[0]
            fig, axs = plt.subplots(4, 1, figsize=(8, 10))
            for i in range(4):
                start = i * num_buses
                end = (i + 1) * num_buses
                sns.kdeplot(dataset[:, start:end].flatten(), label="Ground Truth", ax=axs[i])
                sns.kdeplot(synthetic_data[:, start:end].flatten(), label="Synthetic", ax=axs[i])
                axs[i].set_title(var_names[i])
                axs[i].legend()
            plt.tight_layout()
            plt.show()

            # Additional plots for P, Q, V, θ for five randomly selected buses
            print("   Creating bus-level distribution plots for five buses...")
            np.random.seed(CONFIG['seed'])  # Ensure reproducibility
            selected_buses = np.random.choice(num_buses, 5, replace=False)
            fig, axs = plt.subplots(5, 4, figsize=(16, 12), sharex='col')
            for row, bus_idx in enumerate(selected_buses):
                # Plot P, Q, V, θ for each selected bus
                for col, (var_name, offset) in enumerate(zip(var_names, [0, num_buses, 2*num_buses, 3*num_buses])):
                    idx = offset + bus_idx
                    sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
                    sns.kdeplot(synthetic_data[:, idx], label="Synthetic", ax=axs[row, col])
                    if row == 0:
                        axs[row, col].set_title(f"{var_name}")
                    if col == 0:
                        axs[row, col].set_ylabel(f"Bus {bus_idx}")
                    if row == 4:
                        axs[row, col].set_xlabel(var_name.split(' ')[0])
                    axs[row, col].legend()
            plt.suptitle("Bus-Level Distributions for P, Q, V, θ", fontsize=16)
            plt.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()

            # Joint scatter plots (P vs Q, V vs θ)
            print("   Creating joint density plots...")
            plt.figure(figsize=(10, 4))
            plt.subplot(1, 2, 1)
            sns.kdeplot(
                x=dataset[:, 0], y=dataset[:, num_buses],
                fill=True, cmap="Blues", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 0], y=synthetic_data[:, num_buses],
                color="red", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: P vs Q")

            plt.subplot(1, 2, 2)
            sns.kdeplot(
                x=dataset[:, 2*num_buses], y=dataset[:, 3*num_buses],
                fill=True, cmap="Greens", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 2*num_buses], y=synthetic_data[:, 3*num_buses],
                color="purple", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: V vs θ")
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 4. Utility in Downstream ML Task (Section VI-D)
            # ==============================================================
            print("\n4. Downstream ML Task: Warm-Start Prediction Test")

            import sklearn.model_selection as skms
            import sklearn.neural_network as sknn
            from sklearn.metrics import mean_squared_error

            # Create simple supervised learning task
            # Here we try to learn mapping from (p,q) → (v,θ)
            X_gt = dataset[:, :2*num_buses].numpy()
            y_gt = dataset[:, 2*num_buses:].numpy()

            X_syn = synthetic_data[:, :2*num_buses]
            y_syn = synthetic_data[:, 2*num_buses:]

            # Train-test split
            X_train_gt, X_test_gt, y_train_gt, y_test_gt = skms.train_test_split(X_gt, y_gt, test_size=0.3, random_state=CONFIG['seed'])
            X_train_syn, X_test_syn, y_train_syn, y_test_syn = skms.train_test_split(X_syn, y_syn, test_size=0.3, random_state=CONFIG['seed'])

            # MLP regressor
            def train_mlp(X_train, y_train):
                mlp = sknn.MLPRegressor(hidden_layer_sizes=(128, 128),
                                         activation='relu',
                                         solver='adam',
                                         max_iter=500,
                                         random_state=CONFIG['seed'])
                mlp.fit(X_train, y_train)
                return mlp

            print("   Training baseline (Ground Truth)...")
            mlp_gt = train_mlp(X_train_gt, y_train_gt)
            print("   Training on constrained synthetic data...")
            mlp_syn = train_mlp(X_train_syn, y_train_syn)

            # Evaluate
            y_pred_gt = mlp_gt.predict(X_test_gt)
            y_pred_syn = mlp_syn.predict(X_test_gt)

            mse_gt = mean_squared_error(y_test_gt, y_pred_gt)
            mse_syn = mean_squared_error(y_test_gt, y_pred_syn)

            print(f"   MSE using Ground Truth: {mse_gt:.6f}")
            print(f"   MSE using Synthetic Data: {mse_syn:.6f}")
            print("\n===========================================================")
            print("EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY")
            print("===========================================================")

        else:
            print("Dataset generation failed or returned no samples.")
    else:
        print("Dataset generation failed. Check pandapower installation or seed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 36.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 4.8 MB/s eta 0:00:00
# Using case30 with 30 buses
# Generating 3000 samples...
# Generating Data: 100%|██████████| 3000/3000 [03:07<00:00, 16.02it/s, collected=3000]
# /tmp/ipython-input-685186316.py:536: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")
# /tmp/ipython-input-685186316.py:540: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
# Successfully generated 3000 samples.
#
# Dataset shape: torch.Size([3000, 120])
# Dataset stats:
#   P range: [-43.61, 30.00] MW
#   Q range: [-37.86, 30.00] MVAr
#   V range: [0.963, 1.000] p.u.
#   θ range: [-3.2, 3.7] degrees
#
# Checking ground truth feasibility...
# Ground truth power mismatch (first 10): 12.508062 ± 0.106577
# Warning: Found 21 constant columns. Adding small noise.
# Starting training...
# Epoch 1/100: 100%|██████████| 47/47 [00:00<00:00, 51.54it/s, loss=2.5201]
# Epoch 1 - Average Loss: 3.7354, LR: 0.000100
# Epoch 2/100: 100%|██████████| 47/47 [00:01<00:00, 43.96it/s, loss=1.8383]
# Epoch 2 - Average Loss: 2.0720, LR: 0.000100
# Epoch 3/100: 100%|██████████| 47/47 [00:01<00:00, 41.77it/s, loss=1.6765]
# Epoch 3 - Average Loss: 1.7462, LR: 0.000100
# Epoch 4/100: 100%|██████████| 47/47 [00:01<00:00, 44.06it/s, loss=1.4685]
# Epoch 4 - Average Loss: 1.5578, LR: 0.000100
# Epoch 5/100: 100%|██████████| 47/47 [00:00<00:00, 57.95it/s, loss=1.2751]
# Epoch 5 - Average Loss: 1.3940, LR: 0.000099
# Epoch 6/100: 100%|██████████| 47/47 [00:00<00:00, 56.18it/s, loss=1.1934]
# Epoch 6 - Average Loss: 1.2358, LR: 0.000099
# Epoch 7/100: 100%|██████████| 47/47 [00:00<00:00, 59.50it/s, loss=1.0172]
# Epoch 7 - Average Loss: 1.1143, LR: 0.000099
# Epoch 8/100: 100%|██████████| 47/47 [00:00<00:00, 57.17it/s, loss=0.9747]
# Epoch 8 - Average Loss: 0.9821, LR: 0.000098
# Epoch 9/100: 100%|██████████| 47/47 [00:00<00:00, 56.56it/s, loss=0.8020]
# Epoch 9 - Average Loss: 0.8832, LR: 0.000098
# Epoch 10/100: 100%|██████████| 47/47 [00:00<00:00, 58.48it/s, loss=0.7123]
# Epoch 10 - Average Loss: 0.7953, LR: 0.000098
# Epoch 11/100: 100%|██████████| 47/47 [00:00<00:00, 59.45it/s, loss=0.6376]
# Epoch 11 - Average Loss: 0.7182, LR: 0.000097
# Epoch 12/100: 100%|██████████| 47/47 [00:00<00:00, 60.26it/s, loss=0.5914]
# Epoch 90 - Average Loss: 0.2798, LR: 0.000002
# Epoch 91/100: 100%|██████████| 47/47 [00:01<00:00, 38.37it/s, loss=0.2632]
# Epoch 91 - Average Loss: 0.2788, LR: 0.000002
# Epoch 92/100: 100%|██████████| 47/47 [00:00<00:00, 55.24it/s, loss=0.2990]
# Epoch 92 - Average Loss: 0.2725, LR: 0.000002
# Epoch 93/100: 100%|██████████| 47/47 [00:00<00:00, 54.45it/s, loss=0.2973]
# Epoch 93 - Average Loss: 0.2716, LR: 0.000001
# Epoch 94/100: 100%|██████████| 47/47 [00:00<00:00, 54.52it/s, loss=0.2160]
# Epoch 94 - Average Loss: 0.2673, LR: 0.000001
# Epoch 95/100: 100%|██████████| 47/47 [00:00<00:00, 54.31it/s, loss=0.3262]
# Epoch 95 - Average Loss: 0.2731, LR: 0.000001
# Epoch 96/100: 100%|██████████| 47/47 [00:00<00:00, 54.91it/s, loss=0.2545]
# Epoch 96 - Average Loss: 0.2784, LR: 0.000000
# Epoch 97/100: 100%|██████████| 47/47 [00:00<00:00, 56.05it/s, loss=0.3246]
# Epoch 97 - Average Loss: 0.2780, LR: 0.000000
# Epoch 98/100: 100%|██████████| 47/47 [00:00<00:00, 54.43it/s, loss=0.3062]
# Epoch 98 - Average Loss: 0.2729, LR: 0.000000
# Epoch 99/100: 100%|██████████| 47/47 [00:00<00:00, 52.17it/s, loss=0.2460]
# Epoch 99 - Average Loss: 0.2779, LR: 0.000000
# Epoch 100/100: 100%|██████████| 47/47 [00:00<00:00, 54.67it/s, loss=0.2285]
# Epoch 100 - Average Loss: 0.2515, LR: 0.000000
# Model saved to checkpoint.pth
#
# Generating 50 synthetic samples...
# Starting guided sampling...
# Sampling: 100%|██████████| 1000/1000 [00:03<00:00, 306.09it/s]
# Generating samples:   0%|          | 0/49 [00:00<?, ?it/s]
# Sampling...
# Generating samples:   2%|▏         | 1/49 [00:03<02:29,  3.11s/it]
# Sampling...
# Generating samples:   4%|▍         | 2/49 [00:05<02:17,  2.92s/it]
# Sampling...
# Generating samples:   6%|▌         | 3/49 [00:08<02:09,  2.83s/it]
# Sampling...
# Generating samples:   8%|▊         | 4/49 [00:11<02:05,  2.79s/it]
# Sampling...
# Generating samples:  10%|█         | 5/49 [00:14<02:11,  2.98s/it]
# Sampling...
# Generating samples:  12%|█▏        | 6/49 [00:17<02:02,  2.84s/it]
# Sampling...
# Generating samples:  14%|█▍        | 7/49 [00:19<01:55,  2.76s/it]
# Sampling...
# Generating samples:  16%|█▋        | 8/49 [00:22<01:51,  2.71s/it]
# Sampling...
# Generating samples:  18%|█▊        | 9/49 [00:25<01:54,  2.85s/it]
# Sampling...
# Generating samples:  20%|██        | 10/49 [00:28<01:52,  2.88s/it]
# Sampling...
# Generating samples:  22%|██▏       | 11/49 [00:31<01:47,  2.84s/it]
# Sampling...
# Generating samples:  24%|██▍       | 12/49 [00:33<01:42,  2.76s/it]
# Sampling...
# Generating samples:  27%|██▋       | 13/49 [00:36<01:40,  2.79s/it]
# Sampling...
# Generating samples:  29%|██▊       | 14/49 [00:39<01:42,  2.93s/it]
# Sampling...
# Generating samples:  31%|███       | 15/49 [00:42<01:36,  2.84s/it]
# Sampling...
# Generating samples:  33%|███▎      | 16/49 [00:45<01:30,  2.76s/it]
# Sampling...
# Generating samples:  35%|███▍      | 17/49 [00:47<01:27,  2.73s/it]
# Sampling...
# Generating samples:  37%|███▋      | 18/49 [00:51<01:31,  2.95s/it]
# Sampling...
# Generating samples:  39%|███▉      | 19/49 [00:53<01:25,  2.84s/it]
# Sampling...
# Generating samples:  41%|████      | 20/49 [00:56<01:20,  2.79s/it]
# Sampling...
# Generating samples:  43%|████▎     | 21/49 [00:59<01:16,  2.74s/it]
# Sampling...
# Generating samples:  45%|████▍     | 22/49 [01:02<01:15,  2.80s/it]
# Sampling...
# Generating samples:  47%|████▋     | 23/49 [01:05<01:14,  2.88s/it]
# Sampling...
# Generating samples:  49%|████▉     | 24/49 [01:07<01:09,  2.78s/it]
# Sampling...
# Generating samples:  51%|█████     | 25/49 [01:10<01:05,  2.71s/it]
# Sampling...
# Generating samples:  53%|█████▎    | 26/49 [01:12<01:01,  2.67s/it]
# Sampling...
# Generating samples:  55%|█████▌    | 27/49 [01:16<01:03,  2.90s/it]
# Sampling...
# Generating samples:  57%|█████▋    | 28/49 [01:18<00:58,  2.81s/it]
# Sampling...
# Generating samples:  59%|█████▉    | 29/49 [01:21<00:55,  2.75s/it]
# Sampling...
# Generating samples:  61%|██████    | 30/49 [01:24<00:51,  2.71s/it]
# Sampling...
# Generating samples:  63%|██████▎   | 31/49 [01:27<00:51,  2.86s/it]
# Sampling...
# Generating samples:  65%|██████▌   | 32/49 [01:30<00:48,  2.85s/it]
# Sampling...
# Generating samples:  67%|██████▋   | 33/49 [01:32<00:44,  2.78s/it]
# Sampling...
# Generating samples:  69%|██████▉   | 34/49 [01:35<00:41,  2.74s/it]
# Sampling...
# Generating samples:  71%|███████▏  | 35/49 [01:38<00:37,  2.70s/it]
# Sampling...
# Generating samples:  73%|███████▎  | 36/49 [01:41<00:37,  2.91s/it]
# Sampling...
# Generating samples:  76%|███████▌  | 37/49 [01:43<00:33,  2.80s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 38/49 [01:46<00:29,  2.73s/it]
# Sampling...
# Generating samples:  80%|███████▉  | 39/49 [01:49<00:26,  2.68s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 40/49 [01:52<00:25,  2.82s/it]
# Sampling...
# Generating samples:  84%|████████▎ | 41/49 [01:55<00:22,  2.80s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 42/49 [01:57<00:19,  2.75s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 43/49 [02:00<00:16,  2.70s/it]
# Sampling...
# Generating samples:  90%|████████▉ | 44/49 [02:02<00:13,  2.66s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 45/49 [02:06<00:11,  2.89s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 46/49 [02:08<00:08,  2.80s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 47/49 [02:11<00:05,  2.74s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 48/49 [02:13<00:02,  2.70s/it]
# Sampling...
# Generating samples: 100%|██████████| 49/49 [02:17<00:00,  2.80s/it]
# ============================================================
# VERIFICATION RESULTS (As per Table I and II in the paper)
# ============================================================
#
# 1. Statistical Similarity (Wasserstein Distance):
#    P Wasserstein distance: 0.1232
#    Q Wasserstein distance: 0.0906
#    V Wasserstein distance: 0.0001
#    theta Wasserstein distance: 0.0003
#    Average Wasserstein distance: 0.0536
#
# 2. Constraint Satisfaction (Power Flow Residuals):
#    Synthetic mean mismatch: 12.495869 ± 0.128715
#    Ground truth mean mismatch: 12.508062 ± 0.106577
# 3. Visualizing statistical similarity...
#    Creating bus-level distribution plots for five buses...
# /tmp/ipython-input-685186316.py:630: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-685186316.py:630: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-685186316.py:630: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-685186316.py:630: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
#    Creating joint density plots...
# /tmp/ipython-input-685186316.py:658: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# 4. Downstream ML Task: Warm-Start Prediction Test
#    Training baseline (Ground Truth)...
#    Training on constrained synthetic data...
#    MSE using Ground Truth: 0.008613
#    MSE using Synthetic Data: 0.028672
#
# ===========================================================
# EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY
# ===========================================================

# %%
# Corrected Implementation of "Constrained Diffusion Models for Synthesizing Representative Power Flow Datasets"
# Based on Hoseinpour & Dvorkin (2024)

# 1. Installs
# !pip install torch torchvision torchaudio --quiet
# !pip install pandapower tqdm matplotlib scipy numpy pandas seaborn --quiet

# 2. Imports and Setup
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandapower as pp
import pandapower.networks as pn
import math
import os
import copy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.optimize import linear_sum_assignment
from scipy.spatial.distance import cdist

# 3. Configuration
CONFIG = {
    "system": "case30",
    "num_samples": 2000,  # Increased for better training
    "num_synthetic_samples": 50,  # Number of samples to generate for comparison
    "diffusion_steps": 1000,  # Matched to paper
    "beta_start": 1e-4,
    "beta_end": 0.02,
    "hidden_dim": 256,
    "depth": 5,
    "batch_size": 64,
    "epochs": 100,  # Increased for better convergence
    "lr": 1e-4,
    "lambda_guidance": 0.01,  # Adjusted to paper's range (10^-4 to 10^-2)
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "seed": 42,
}

# 4. Model and Utility Definitions
class SinusoidalTimeEmbedding(nn.Module):
    """Sinusoidal positional encoding for time steps"""
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, t):
        device = t.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = t[:, None] * emb[None, :]
        return torch.cat((torch.sin(emb), torch.cos(emb)), dim=-1)

class DenoiserMLP(nn.Module):
    """Denoiser neural network ε_θ as described in the paper"""
    def __init__(self, dim_in, hidden=256, depth=3, time_embed_dim=128):
        super().__init__()
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)

        layers = []
        for i in range(depth):
            in_dim = dim_in + time_embed_dim if i == 0 else hidden
            out_dim = hidden if i < depth - 1 else dim_in
            layers.append(nn.Linear(in_dim, out_dim))
            if i < depth - 1:
                layers.append(nn.SiLU())  # Using SiLU (Swish) activation
                layers.append(nn.LayerNorm(out_dim))

        self.net = nn.Sequential(*layers)

        # Initialize weights
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_normal_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x, t):
        t_emb = self.time_embed(t.float())
        h = torch.cat([x, t_emb], dim=-1)
        return self.net(h)

class MinMaxNorm:
    """Min-max normalization to [-1, 1] range as per Section V-B of the paper"""
    def __init__(self, xmin, xmax, eps=1e-8):
        self.xmin = xmin.clone().detach() if isinstance(xmin, torch.Tensor) else torch.tensor(xmin, dtype=torch.float32)
        self.xmax = xmax.clone().detach() if isinstance(xmax, torch.Tensor) else torch.tensor(xmax, dtype=torch.float32)
        self.eps = eps
        self.range = torch.clamp(self.xmax - self.xmin, min=eps)

    def norm(self, x):
        """Normalize to [-1, 1] using equation (30)"""
        return 2 * (x - self.xmin.to(x.device)) / self.range.to(x.device) - 1

    def denorm(self, x):
        """Denormalize using equation (31)"""
        return ((x + 1) / 2) * self.range.to(x.device) + self.xmin.to(x.device)

    def scale_gradient(self, grad):
        """Scale gradient according to equation (32)"""
        return grad * 2 / self.range.to(grad.device)

def make_beta_schedule(T, beta_start=1e-4, beta_end=0.02, schedule='linear'):
    """Create noise schedule as described in Section III-A"""
    if schedule == 'linear':
        betas = torch.linspace(beta_start, beta_end, T)
    elif schedule == 'cosine':
        # Alternative cosine schedule
        s = 0.008
        steps = T + 1
        x = torch.linspace(0, T, steps)
        alphas_cumprod = torch.cos(((x / T) + s) / (1 + s) * torch.pi * 0.5) ** 2
        alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
        betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
        betas = torch.clip(betas, beta_start, beta_end)

    alphas = 1.0 - betas
    alpha_bar = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bar

def power_flow_residual(x_phys, G, B):
    """
    Compute power flow residual based on Equations (8a) and (8b) from the paper.
    This is the correct formulation using power balance equations.
    """
    Bdim = G.shape[0]
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    batch_size = x_phys.shape[0]
    device = x_phys.device

    # Ensure G and B are tensors on the correct device
    if not isinstance(G, torch.Tensor):
        G = torch.tensor(G, dtype=torch.float32, device=device)
    if not isinstance(B, torch.Tensor):
        B = torch.tensor(B, dtype=torch.float32, device=device)

    # Expand dimensions for broadcasting
    v_i = v.unsqueeze(2)  # [batch, Bdim, 1]
    v_j = v.unsqueeze(1)  # [batch, 1, Bdim]
    theta_i = theta.unsqueeze(2)  # [batch, Bdim, 1]
    theta_j = theta.unsqueeze(1)  # [batch, 1, Bdim]

    # Calculate angle differences
    theta_diff = theta_i - theta_j  # [batch, Bdim, Bdim]

    # Power flow equations from the paper
    # P_i = Σ_j v_i * v_j * (G_ij * cos(θ_i - θ_j) + B_ij * sin(θ_i - θ_j))
    P_calc = torch.sum(v_i * v_j * (G * torch.cos(theta_diff) + B * torch.sin(theta_diff)), dim=2)

    # Q_i = Σ_j v_i * v_j * (G_ij * sin(θ_i - θ_j) - B_ij * cos(θ_i - θ_j))
    Q_calc = torch.sum(v_i * v_j * (G * torch.sin(theta_diff) - B * torch.cos(theta_diff)), dim=2)

    # Residuals (power balance mismatch)
    p_residual = p - P_calc
    q_residual = q - Q_calc

    return torch.cat([p_residual, q_residual], dim=-1)

def compute_inequality_violations(x_phys, net):
    """Compute violations of inequality constraints (10a-10d)"""
    Bdim = len(net.bus)
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    violations = []

    # Voltage limits (10c)
    v_min = torch.tensor(net.bus.min_vm_pu.values, device=x_phys.device)
    v_max = torch.tensor(net.bus.max_vm_pu.values, device=x_phys.device)
    violations.append(torch.relu(v_min - v))  # v >= v_min
    violations.append(torch.relu(v - v_max))  # v <= v_max

    return torch.cat(violations, dim=-1)

def make_dataset(net_fn, N=500, scale_range=(0.8, 1.0), seed=0):
    """Generate ground truth dataset by solving AC-OPF as described in Section VI-A"""
    np.random.seed(seed)
    torch.manual_seed(seed)

    net = net_fn()
    base_loads_p = net.load["p_mw"].copy()
    base_loads_q = net.load["q_mvar"].copy()

    samples = []
    print(f"Generating {N} samples...")

    pbar = tqdm(range(N), desc="Generating Data")
    for _ in pbar:
        net_temp = copy.deepcopy(net)

        # Sample load scaling factors uniformly as in the paper
        scale_p = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))
        scale_q = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))

        net_temp.load["p_mw"] = base_loads_p * scale_p
        net_temp.load["q_mvar"] = base_loads_q * scale_q

        try:
            # Run power flow (not OPF for simplicity in this implementation)
            pp.runpp(net_temp, algorithm='nr', init='dc', numba=False, max_iteration=50)

            if net_temp.converged:
                # Extract power injections and voltages
                p = net_temp.res_bus.p_mw.values
                q = net_temp.res_bus.q_mvar.values
                v = net_temp.res_bus.vm_pu.values
                theta = np.deg2rad(net_temp.res_bus.va_degree.values)

                # Stack into single vector
                sample = np.concatenate([p, q, v, theta])
                samples.append(sample)
                pbar.set_postfix({"collected": len(samples)})

        except Exception as e:
            continue

    print(f"Successfully generated {len(samples)} samples.")
    return torch.tensor(np.array(samples), dtype=torch.float32)

def train_model(data, B, config):
    """Train diffusion model with variable decoupling (Algorithm 4)"""
    device = config["device"]
    T = config["diffusion_steps"]

    # Create noise schedule
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Initialize denoiser networks for variable decoupling
    den1 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)

    # Normalization
    data_min = data.min(0).values
    data_max = data.max(0).values

    # Add small noise to constant columns
    data_range = data_max - data_min
    constant_mask = data_range < 1e-6
    if constant_mask.any():
        print(f"Warning: Found {constant_mask.sum().item()} constant columns. Adding small noise.")
        data_min[constant_mask] -= 1e-4
        data_max[constant_mask] += 1e-4

    normer = MinMaxNorm(data_min, data_max)
    data_norm = normer.norm(data)

    # Check for NaN/Inf
    if torch.isnan(data_norm).any() or torch.isinf(data_norm).any():
        print("ERROR: NaN or Inf detected after normalization!")
        return None, None, None, None

    # Create dataloader
    loader = DataLoader(TensorDataset(data_norm), batch_size=config["batch_size"], shuffle=True)

    # Optimizer
    opt = torch.optim.AdamW(
        list(den1.parameters()) + list(den2.parameters()),
        lr=config["lr"],
        weight_decay=1e-5
    )

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=config["epochs"])

    loss_history = []

    print("Starting training...")
    for ep in range(config["epochs"]):
        total_loss = 0
        num_batches = 0

        pbar = tqdm(loader, desc=f"Epoch {ep+1}/{config['epochs']}")

        for (xb,) in pbar:
            xb = xb.to(device)

            # Variable decoupling: split into (p,θ) and (q,v)
            x1 = torch.cat([xb[:, :B], xb[:, 3*B:4*B]], dim=-1)  # (p, θ)
            x2 = torch.cat([xb[:, B:2*B], xb[:, 2*B:3*B]], dim=-1)  # (q, v)

            # Sample random timesteps
            t = torch.randint(0, T, (xb.size(0),), device=device)

            # Sample noise
            eps1 = torch.randn_like(x1)
            eps2 = torch.randn_like(x2)

            # Forward diffusion (equation 3)
            sqrt_ab_t = torch.sqrt(alpha_bar[t]).unsqueeze(-1)
            sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t]).unsqueeze(-1)

            x1_t = sqrt_ab_t * x1 + sqrt_1_minus_ab_t * eps1
            x2_t = sqrt_ab_t * x2 + sqrt_1_minus_ab_t * eps2

            # Predict noise
            pred1 = den1(x1_t, t)
            pred2 = den2(x2_t, t)

            # MSE loss (equation 5)
            loss1 = ((eps1 - pred1)**2).mean()
            loss2 = ((eps2 - pred2)**2).mean()
            loss = loss1 + loss2

            # Check for NaN
            if torch.isnan(loss):
                print(f"\nNaN loss detected at epoch {ep+1}!")
                break

            opt.zero_grad()
            loss.backward()

            # Gradient clipping for stability
            torch.nn.utils.clip_grad_norm_(
                list(den1.parameters()) + list(den2.parameters()),
                max_norm=1.0
            )

            opt.step()

            total_loss += loss.item()
            num_batches += 1
            pbar.set_postfix(loss=f"{loss.item():.4f}")

        scheduler.step()

        avg_loss = total_loss / num_batches
        loss_history.append(avg_loss)
        print(f"Epoch {ep+1} - Average Loss: {avg_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}")

    # Save checkpoint
    checkpoint = {
        "den1": den1.state_dict(),
        "den2": den2.state_dict(),
        "xmin": normer.xmin,
        "xmax": normer.xmax,
        "range": normer.range,
        "B": B
    }
    torch.save(checkpoint, "checkpoint.pth")
    print("Model saved to checkpoint.pth")

    return den1, den2, normer, loss_history

def sample_with_guidance(G, Bmat, config, ckpt_path="checkpoint.pth", track_residuals=False):
    """Sampling with manifold-constrained gradient guidance (Algorithm 5)"""
    device = config["device"]

    # Load checkpoint
    ckpt = torch.load(ckpt_path, map_location=device)
    Bdim = ckpt["B"]

    # Initialize denoisers
    den1 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den1.load_state_dict(ckpt["den1"])
    den2.load_state_dict(ckpt["den2"])
    den1.eval()
    den2.eval()

    # Normalizer
    normer = MinMaxNorm(ckpt["xmin"], ckpt["xmax"])
    if "range" in ckpt:
        normer.range = ckpt["range"]

    # Noise schedule
    T = config["diffusion_steps"]
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Guidance strength
    lam = config["lambda_guidance"]

    # Initialize from pure noise
    x_t = torch.randn(1, 4 * Bdim, device=device)

    # Track residuals if requested
    residual_history = [] if track_residuals else None

    print("Starting guided sampling..." if track_residuals else "Sampling...")
    pbar = tqdm(reversed(range(T)), desc="Sampling", total=T, disable=not track_residuals)

    for t in pbar:
        # Split for variable decoupling
        x1_t = torch.cat([x_t[:, :Bdim], x_t[:, 3*Bdim:4*Bdim]], dim=-1)  # (p, θ)
        x2_t = torch.cat([x_t[:, Bdim:2*Bdim], x_t[:, 2*Bdim:3*Bdim]], dim=-1)  # (q, v)

        with torch.no_grad():
            t_tensor = torch.tensor([t], device=device)

            # Predict noise (denoisers)
            eps1 = den1(x1_t, t_tensor)
            eps2 = den2(x2_t, t_tensor)

        # Estimate clean data using Tweedie's formula (equation 6)
        sqrt_ab_t = torch.sqrt(alpha_bar[t])
        sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t])

        hat_x0_p1 = (x1_t - sqrt_1_minus_ab_t * eps1) / (sqrt_ab_t + 1e-8)
        hat_x0_p2 = (x2_t - sqrt_1_minus_ab_t * eps2) / (sqrt_ab_t + 1e-8)

        # Reconstruct full vector
        hat_x0_norm = torch.zeros(1, 4*Bdim, device=device)
        hat_x0_norm[:, :Bdim] = hat_x0_p1[:, :Bdim]  # p
        hat_x0_norm[:, Bdim:2*Bdim] = hat_x0_p2[:, :Bdim]  # q
        hat_x0_norm[:, 2*Bdim:3*Bdim] = hat_x0_p2[:, Bdim:2*Bdim]  # v
        hat_x0_norm[:, 3*Bdim:4*Bdim] = hat_x0_p1[:, Bdim:2*Bdim]  # θ

        # Clamp for stability
        hat_x0_norm = torch.clamp(hat_x0_norm, -3, 3)

        # Apply gradient guidance if lambda > 0
        if lam > 0 and t > 0:  # No guidance at t=0
            hat_x0_norm.requires_grad_(True)

            # Denormalize for physics evaluation
            x_phys = normer.denorm(hat_x0_norm)

            # Compute power flow residual
            residual = power_flow_residual(x_phys, G, Bmat)
            residual_loss = (residual**2).sum()

            if track_residuals:
                residual_history.append(torch.sqrt(residual_loss).item())

            if not torch.isnan(residual_loss):
                # Compute gradient with respect to normalized variables
                grad_norm = torch.autograd.grad(residual_loss, hat_x0_norm, create_graph=False)[0]

                # Scale gradient properly
                grad_norm = normer.scale_gradient(grad_norm)

                # Clip gradient for stability
                grad_norm = torch.clamp(grad_norm, -1.0, 1.0)

                # Apply guidance (equation 23)
                guidance_strength = lam * (1 - t/T)  # Decay guidance over time
                hat_x0_guided = hat_x0_norm - guidance_strength * grad_norm
                hat_x0_guided = hat_x0_guided.detach()
            else:
                hat_x0_guided = hat_x0_norm.detach()
        else:
            hat_x0_guided = hat_x0_norm.detach()

        # Split guided estimate for variable decoupling
        hat_x0_guided_p1 = torch.cat([hat_x0_guided[:, :Bdim], hat_x0_guided[:, 3*Bdim:4*Bdim]], dim=-1)
        hat_x0_guided_p2 = torch.cat([hat_x0_guided[:, Bdim:2*Bdim], hat_x0_guided[:, 2*Bdim:3*Bdim]], dim=-1)

        # Reverse diffusion step (equation 7)
        if t > 0:
            z = torch.randn_like(x_t)
            z1 = torch.cat([z[:, :Bdim], z[:, 3*Bdim:4*Bdim]], dim=-1)
            z2 = torch.cat([z[:, Bdim:2*Bdim], z[:, 2*Bdim:3*Bdim]], dim=-1)
        else:
            z1 = z2 = 0

        beta_t = betas[t]
        alpha_t = alphas[t]
        alpha_bar_prev = alpha_bar[t-1] if t > 0 else torch.tensor(1.0, device=device)

        # DDPM sampling coefficients
        coef1 = torch.sqrt(alpha_bar_prev) * beta_t / (1 - alpha_bar[t] + 1e-8)
        coef2 = torch.sqrt(alpha_t) * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8)
        sigma_t = torch.sqrt(beta_t * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8))

        # Update x1_t and x2_t
        x1_t = coef1 * hat_x0_guided_p1 + coef2 * x1_t + sigma_t * z1
        x2_t = coef1 * hat_x0_guided_p2 + coef2 * x2_t + sigma_t * z2

        # Reconstruct full x_t
        x_t[:, :Bdim] = x1_t[:, :Bdim]
        x_t[:, Bdim:2*Bdim] = x2_t[:, :Bdim]
        x_t[:, 2*Bdim:3*Bdim] = x2_t[:, Bdim:2*Bdim]
        x_t[:, 3*Bdim:4*Bdim] = x1_t[:, Bdim:2*Bdim]

    # Final denormalization
    final_sample = normer.denorm(x_t).cpu().numpy()

    if track_residuals:
        return final_sample, residual_history
    return final_sample

def compute_wasserstein_distance(data1, data2):
    """Compute joint type-1 Wasserstein distance using Euclidean norm as cost"""
    cost_matrix = cdist(data1, data2, metric='euclidean')
    row_ind, col_ind = linear_sum_assignment(cost_matrix)
    total_cost = cost_matrix[row_ind, col_ind].sum()
    w_distance = total_cost / data1.shape[0]
    return w_distance

# 5. Main Execution with Verification
if __name__ == "__main__":
    torch.manual_seed(CONFIG['seed'])
    np.random.seed(CONFIG['seed'])

    # Load network
    network_function = getattr(pn, CONFIG['system'])
    net = network_function()
    num_buses = len(net.bus)
    print(f"Using {CONFIG['system']} with {num_buses} buses")

    # Get admittance matrix
    pp.runpp(net)
    Ybus = net._ppc['internal']['Ybus']
    G_matrix, B_matrix = Ybus.real.toarray(), Ybus.imag.toarray()

    # Generate ground truth dataset
    dataset = make_dataset(network_function, N=CONFIG['num_samples'], seed=CONFIG['seed'])

    if len(dataset) > 0:
        print(f"\nDataset shape: {dataset.shape}")
        print(f"Dataset stats:")
        print(f"  P range: [{dataset[:, :num_buses].min():.2f}, {dataset[:, :num_buses].max():.2f}] MW")
        print(f"  Q range: [{dataset[:, num_buses:2*num_buses].min():.2f}, {dataset[:, num_buses:2*num_buses].max():.2f}] MVAr")
        print(f"  V range: [{dataset[:, 2*num_buses:3*num_buses].min():.3f}, {dataset[:, 2*num_buses:3*num_buses].max():.3f}] p.u.")
        print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")

        # Check ground truth feasibility
        print("\nChecking ground truth feasibility...")
        gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
        gt_residuals = power_flow_residual(gt_tensor, G_matrix, B_matrix)
        gt_mismatch = torch.sqrt((gt_residuals**2).mean(dim=1))
        print(f"Ground truth power mismatch (first 10): {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

        # Train the diffusion model
        den1, den2, normer, loss_history = train_model(dataset, num_buses, CONFIG)

        if den1 is not None:
            # Plot training loss
            plt.figure(figsize=(6, 4))
            plt.plot(range(1, len(loss_history) + 1), loss_history, linewidth=2)
            plt.xlabel("Epoch")
            plt.ylabel("Average Loss")
            plt.title("Training Loss over Epochs")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # Generate synthetic samples
            print(f"\nGenerating {CONFIG['num_synthetic_samples']} synthetic samples...")
            synthetic_samples = []

            # First sample with residual tracking
            first_sample, residual_history = sample_with_guidance(
                G_matrix, B_matrix, CONFIG, track_residuals=True
            )
            synthetic_samples.append(first_sample[0])

            # Generate remaining samples
            for i in tqdm(range(1, CONFIG['num_synthetic_samples']), desc="Generating samples"):
                sample = sample_with_guidance(G_matrix, B_matrix, CONFIG, track_residuals=False)
                synthetic_samples.append(sample[0])

            synthetic_data = np.array(synthetic_samples)
            ground_truth_data = dataset.numpy()

            # Verification Results
            print("\n" + "="*60)
            print("VERIFICATION RESULTS (As per Table I and II in the paper)")
            print("="*60)

            # 1. Wasserstein Distance (Table I)
            print("\n1. Statistical Similarity (Wasserstein Distance):")
            subset_size = min(1000, len(ground_truth_data), len(synthetic_data))
            w_distance = compute_wasserstein_distance(
                ground_truth_data[:subset_size],
                synthetic_data[:subset_size]
            )
            print(f"   Wasserstein distance: {w_distance:.4f}")

            # ==============================================================
            # 2. Constraint Satisfaction (Section VI-C)
            # ==============================================================
            print("\n2. Constraint Satisfaction (Power Flow Residuals):")
            synth_tensor = torch.tensor(synthetic_data, dtype=torch.float32)
            synth_residuals = power_flow_residual(synth_tensor, G_matrix, B_matrix)
            synth_mismatch = torch.sqrt((synth_residuals ** 2).mean(dim=1))
            print(f"   Synthetic mean mismatch: {synth_mismatch.mean():.6f} ± {synth_mismatch.std():.6f}")
            print(f"   Ground truth mean mismatch: {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

            # Plot residual convergence history
            plt.figure(figsize=(6, 4))
            plt.plot(residual_history, linewidth=2)
            plt.xlabel("Diffusion step (t)")
            plt.ylabel("Residual norm ||H(x)||₂")
            plt.title("Residual Convergence During Guided Sampling")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 3. Visual Comparison (Section VI-B figures)
            # ==============================================================
            print("\n3. Visualizing statistical similarity...")

            var_names = ['P (MW)', 'Q (MVAr)', 'V (p.u.)', 'θ (rad)']
            num_buses = G_matrix.shape[0]
            fig, axs = plt.subplots(4, 1, figsize=(8, 10))
            for i in range(4):
                start = i * num_buses
                end = (i + 1) * num_buses
                sns.kdeplot(dataset[:, start:end].flatten(), label="Ground Truth", ax=axs[i])
                sns.kdeplot(synthetic_data[:, start:end].flatten(), label="Synthetic", ax=axs[i])
                axs[i].set_title(var_names[i])
                axs[i].legend()
            plt.tight_layout()
            plt.show()

            # Additional plots for P, Q, V, θ for five randomly selected buses
            print("   Creating bus-level distribution plots for five buses...")
            np.random.seed(CONFIG['seed'])  # Ensure reproducibility
            selected_buses = np.random.choice(num_buses, 5, replace=False)
            fig, axs = plt.subplots(5, 4, figsize=(16, 12), sharex='col')
            for row, bus_idx in enumerate(selected_buses):
                # Plot P, Q, V, θ for each selected bus
                for col, (var_name, offset) in enumerate(zip(var_names, [0, num_buses, 2*num_buses, 3*num_buses])):
                    idx = offset + bus_idx
                    sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
                    sns.kdeplot(synthetic_data[:, idx], label="Synthetic", ax=axs[row, col])
                    if row == 0:
                        axs[row, col].set_title(f"{var_name}")
                    if col == 0:
                        axs[row, col].set_ylabel(f"Bus {bus_idx}")
                    if row == 4:
                        axs[row, col].set_xlabel(var_name.split(' ')[0])
                    axs[row, col].legend()
            plt.suptitle("Bus-Level Distributions for P, Q, V, θ", fontsize=16)
            plt.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()

            # Joint scatter plots (P vs Q, V vs θ)
            print("   Creating joint density plots...")
            plt.figure(figsize=(10, 4))
            plt.subplot(1, 2, 1)
            sns.kdeplot(
                x=dataset[:, 0], y=dataset[:, num_buses],
                fill=True, cmap="Blues", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 0], y=synthetic_data[:, num_buses],
                color="red", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: P vs Q")

            plt.subplot(1, 2, 2)
            sns.kdeplot(
                x=dataset[:, 2*num_buses], y=dataset[:, 3*num_buses],
                fill=True, cmap="Greens", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 2*num_buses], y=synthetic_data[:, 3*num_buses],
                color="purple", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: V vs θ")
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 4. Utility in Downstream ML Task (Section VI-D)
            # ==============================================================
            print("\n4. Downstream ML Task: Warm-Start Prediction Test")

            import sklearn.model_selection as skms
            import sklearn.neural_network as sknn
            from sklearn.metrics import mean_squared_error

            # Create simple supervised learning task
            # Here we try to learn mapping from (p,q) → (v,θ)
            X_gt = dataset[:, :2*num_buses].numpy()
            y_gt = dataset[:, 2*num_buses:].numpy()

            X_syn = synthetic_data[:, :2*num_buses]
            y_syn = synthetic_data[:, 2*num_buses:]

            # Train-test split
            X_train_gt, X_test_gt, y_train_gt, y_test_gt = skms.train_test_split(X_gt, y_gt, test_size=0.3, random_state=CONFIG['seed'])
            X_train_syn, X_test_syn, y_train_syn, y_test_syn = skms.train_test_split(X_syn, y_syn, test_size=0.3, random_state=CONFIG['seed'])

            # MLP regressor
            def train_mlp(X_train, y_train):
                mlp = sknn.MLPRegressor(hidden_layer_sizes=(128, 128),
                                         activation='relu',
                                         solver='adam',
                                         max_iter=500,
                                         random_state=CONFIG['seed'])
                mlp.fit(X_train, y_train)
                return mlp

            print("   Training baseline (Ground Truth)...")
            mlp_gt = train_mlp(X_train_gt, y_train_gt)
            print("   Training on constrained synthetic data...")
            mlp_syn = train_mlp(X_train_syn, y_train_syn)

            # Evaluate
            y_pred_gt = mlp_gt.predict(X_test_gt)
            y_pred_syn = mlp_syn.predict(X_test_gt)

            mse_gt = mean_squared_error(y_test_gt, y_pred_gt)
            mse_syn = mean_squared_error(y_test_gt, y_pred_syn)

            print(f"   MSE using Ground Truth: {mse_gt:.6f}")
            print(f"   MSE using Synthetic Data: {mse_syn:.6f}")
            print("\n===========================================================")
            print("EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY")
            print("===========================================================")

        else:
            print("Dataset generation failed or returned no samples.")
    else:
        print("Dataset generation failed. Check pandapower installation or seed.")
# Out:
# Using case30 with 30 buses
# Generating 2000 samples...
# Generating Data: 100%|██████████| 2000/2000 [02:08<00:00, 15.52it/s, collected=2000]
# /tmp/ipython-input-47696701.py:525: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")
# /tmp/ipython-input-47696701.py:529: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
# Successfully generated 2000 samples.
#
# Dataset shape: torch.Size([2000, 120])
# Dataset stats:
#   P range: [-43.61, 30.00] MW
#   Q range: [-37.79, 30.00] MVAr
#   V range: [0.963, 1.000] p.u.
#   θ range: [-3.2, 3.6] degrees
#
# Checking ground truth feasibility...
# Ground truth power mismatch (first 10): 12.508062 ± 0.106577
# Warning: Found 21 constant columns. Adding small noise.
# Starting training...
# Epoch 1/100: 100%|██████████| 32/32 [00:00<00:00, 59.92it/s, loss=3.3508]
# Epoch 1 - Average Loss: 4.1524, LR: 0.000100
# Epoch 2/100: 100%|██████████| 32/32 [00:00<00:00, 57.04it/s, loss=2.1614]
# Epoch 2 - Average Loss: 2.5688, LR: 0.000100
# Epoch 3/100: 100%|██████████| 32/32 [00:00<00:00, 59.63it/s, loss=1.9227]
# Epoch 3 - Average Loss: 1.9552, LR: 0.000100
# Epoch 4/100: 100%|██████████| 32/32 [00:00<00:00, 56.25it/s, loss=1.7469]
# Epoch 4 - Average Loss: 1.7821, LR: 0.000100
# Epoch 5/100: 100%|██████████| 32/32 [00:00<00:00, 58.06it/s, loss=1.4955]
# Epoch 5 - Average Loss: 1.6373, LR: 0.000099
# Epoch 6/100: 100%|██████████| 32/32 [00:00<00:00, 57.90it/s, loss=1.5571]
# Epoch 6 - Average Loss: 1.5154, LR: 0.000099
# Epoch 7/100: 100%|██████████| 32/32 [00:00<00:00, 58.25it/s, loss=1.3493]
# Epoch 7 - Average Loss: 1.4106, LR: 0.000099
# Epoch 8/100: 100%|██████████| 32/32 [00:00<00:00, 59.45it/s, loss=1.1592]
# Epoch 8 - Average Loss: 1.2970, LR: 0.000098
# Epoch 9/100: 100%|██████████| 32/32 [00:00<00:00, 47.24it/s, loss=1.1823]
# Epoch 9 - Average Loss: 1.2093, LR: 0.000098
# Epoch 10/100: 100%|██████████| 32/32 [00:00<00:00, 43.63it/s, loss=1.2500]
# Epoch 10 - Average Loss: 1.1422, LR: 0.000098
# Epoch 11/100: 100%|██████████| 32/32 [00:00<00:00, 44.16it/s, loss=1.1258]
# Epoch 11 - Average Loss: 1.0340, LR: 0.000097
# Epoch 12/100: 100%|██████████| 32/32 [00:00<00:00, 40.02it/s, loss=0.9915]
# Epoch 12 - Average Loss: 0.9793, LR: 0.000096
# Epoch 13/100: 100%|██████████| 32/32 [00:00<00:00, 58.10it/s, loss=0.9183]
# Epoch 13 - Average Loss: 0.8988, LR: 0.000096
# Epoch 14/100: 100%|██████████| 32/32 [00:00<00:00, 57.83it/s, loss=0.8161]
# Epoch 14 - Average Loss: 0.8360, LR: 0.000095
# Epoch 15/100: 100%|██████████| 32/32 [00:00<00:00, 60.78it/s, loss=0.7848]
# Epoch 15 - Average Loss: 0.7830, LR: 0.000095
# Epoch 16/100: 100%|██████████| 32/32 [00:00<00:00, 58.87it/s, loss=0.6796]
# Epoch 16 - Average Loss: 0.7385, LR: 0.000094
# Epoch 17/100: 100%|██████████| 32/32 [00:00<00:00, 42.49it/s, loss=0.7789]
# Epoch 17 - Average Loss: 0.6944, LR: 0.000093
# Epoch 18/100: 100%|██████████| 32/32 [00:01<00:00, 29.45it/s, loss=0.6640]
# Epoch 18 - Average Loss: 0.6354, LR: 0.000092
# Epoch 19/100: 100%|██████████| 32/32 [00:01<00:00, 25.78it/s, loss=0.5244]
# Epoch 19 - Average Loss: 0.6223, LR: 0.000091
# Epoch 20/100: 100%|██████████| 32/32 [00:01<00:00, 29.18it/s, loss=0.6732]
# Epoch 20 - Average Loss: 0.5764, LR: 0.000090
# Epoch 21/100: 100%|██████████| 32/32 [00:01<00:00, 28.10it/s, loss=0.6252]
# Epoch 21 - Average Loss: 0.5546, LR: 0.000090
# Epoch 22/100: 100%|██████████| 32/32 [00:01<00:00, 31.13it/s, loss=0.4431]
# Epoch 41 - Average Loss: 0.3584, LR: 0.000064
# Epoch 42/100: 100%|██████████| 32/32 [00:00<00:00, 56.49it/s, loss=0.4065]
# Epoch 42 - Average Loss: 0.3513, LR: 0.000062
# Epoch 43/100: 100%|██████████| 32/32 [00:00<00:00, 47.80it/s, loss=0.3149]
# Epoch 43 - Average Loss: 0.3553, LR: 0.000061
# Epoch 44/100: 100%|██████████| 32/32 [00:00<00:00, 41.29it/s, loss=0.3942]
# Epoch 44 - Average Loss: 0.3460, LR: 0.000059
# Epoch 45/100: 100%|██████████| 32/32 [00:00<00:00, 46.56it/s, loss=0.3307]
# Epoch 45 - Average Loss: 0.3511, LR: 0.000058
# Epoch 46/100: 100%|██████████| 32/32 [00:00<00:00, 39.71it/s, loss=0.3687]
# Epoch 46 - Average Loss: 0.3519, LR: 0.000056
# Epoch 47/100: 100%|██████████| 32/32 [00:00<00:00, 53.90it/s, loss=0.3337]
# Epoch 47 - Average Loss: 0.3479, LR: 0.000055
# Epoch 48/100: 100%|██████████| 32/32 [00:00<00:00, 56.64it/s, loss=0.4100]
# Epoch 48 - Average Loss: 0.3554, LR: 0.000053
# Epoch 49/100: 100%|██████████| 32/32 [00:00<00:00, 56.96it/s, loss=0.3311]
# Epoch 49 - Average Loss: 0.3227, LR: 0.000052
# Epoch 50/100: 100%|██████████| 32/32 [00:00<00:00, 57.72it/s, loss=0.2759]
# Epoch 50 - Average Loss: 0.3379, LR: 0.000050
# Epoch 51/100: 100%|██████████| 32/32 [00:00<00:00, 57.22it/s, loss=0.3680]
# Epoch 51 - Average Loss: 0.3472, LR: 0.000048
# Epoch 52/100: 100%|██████████| 32/32 [00:00<00:00, 56.44it/s, loss=0.3841]
# Epoch 52 - Average Loss: 0.3157, LR: 0.000047
# Epoch 53/100: 100%|██████████| 32/32 [00:00<00:00, 60.19it/s, loss=0.2931]
# Epoch 53 - Average Loss: 0.3225, LR: 0.000045
# Epoch 54/100: 100%|██████████| 32/32 [00:00<00:00, 58.46it/s, loss=0.2922]
# Epoch 54 - Average Loss: 0.3258, LR: 0.000044
# Epoch 55/100: 100%|██████████| 32/32 [00:00<00:00, 56.76it/s, loss=0.2656]
# Epoch 55 - Average Loss: 0.3445, LR: 0.000042
# Epoch 56/100: 100%|██████████| 32/32 [00:00<00:00, 55.86it/s, loss=0.3444]
# Epoch 56 - Average Loss: 0.3303, LR: 0.000041
# Epoch 57/100: 100%|██████████| 32/32 [00:00<00:00, 60.06it/s, loss=0.2781]
# Epoch 57 - Average Loss: 0.3277, LR: 0.000039
# Epoch 58/100: 100%|██████████| 32/32 [00:00<00:00, 56.19it/s, loss=0.3137]
# Epoch 58 - Average Loss: 0.3335, LR: 0.000038
# Epoch 59/100: 100%|██████████| 32/32 [00:00<00:00, 58.26it/s, loss=0.5137]
# Epoch 59 - Average Loss: 0.3187, LR: 0.000036
# Epoch 60/100: 100%|██████████| 32/32 [00:00<00:00, 56.89it/s, loss=0.2755]
# Epoch 60 - Average Loss: 0.3150, LR: 0.000035
# Epoch 61/100: 100%|██████████| 32/32 [00:00<00:00, 58.12it/s, loss=0.2952]
# Epoch 61 - Average Loss: 0.3246, LR: 0.000033
# Epoch 62/100: 100%|██████████| 32/32 [00:00<00:00, 55.72it/s, loss=0.1933]
# Epoch 62 - Average Loss: 0.3123, LR: 0.000032
# Epoch 63/100: 100%|██████████| 32/32 [00:00<00:00, 56.60it/s, loss=0.2858]
# Epoch 63 - Average Loss: 0.3012, LR: 0.000030
# Epoch 64/100: 100%|██████████| 32/32 [00:00<00:00, 54.87it/s, loss=0.5508]
# Epoch 64 - Average Loss: 0.3244, LR: 0.000029
# Epoch 65/100: 100%|██████████| 32/32 [00:00<00:00, 41.52it/s, loss=0.3794]
# Epoch 65 - Average Loss: 0.3008, LR: 0.000027
# Epoch 66/100: 100%|██████████| 32/32 [00:00<00:00, 45.95it/s, loss=0.2788]
# Epoch 66 - Average Loss: 0.3406, LR: 0.000026
# Epoch 67/100: 100%|██████████| 32/32 [00:00<00:00, 44.12it/s, loss=0.5214]
# Epoch 67 - Average Loss: 0.3123, LR: 0.000025
# Epoch 68/100: 100%|██████████| 32/32 [00:00<00:00, 39.51it/s, loss=0.5741]
# Epoch 68 - Average Loss: 0.3341, LR: 0.000023
# Epoch 69/100: 100%|██████████| 32/32 [00:00<00:00, 56.92it/s, loss=0.2597]
# Epoch 69 - Average Loss: 0.3216, LR: 0.000022
# Epoch 70/100: 100%|██████████| 32/32 [00:00<00:00, 54.64it/s, loss=0.3298]
# Epoch 70 - Average Loss: 0.3209, LR: 0.000021
# Epoch 71/100: 100%|██████████| 32/32 [00:00<00:00, 58.19it/s, loss=0.3069]
# Epoch 71 - Average Loss: 0.3190, LR: 0.000019
# Epoch 72/100: 100%|██████████| 32/32 [00:00<00:00, 56.54it/s, loss=0.2245]
# Epoch 72 - Average Loss: 0.3091, LR: 0.000018
# Epoch 73/100: 100%|██████████| 32/32 [00:00<00:00, 56.85it/s, loss=0.2303]
# Epoch 73 - Average Loss: 0.3114, LR: 0.000017
# Epoch 74/100: 100%|██████████| 32/32 [00:00<00:00, 57.84it/s, loss=0.3446]
# Epoch 74 - Average Loss: 0.3335, LR: 0.000016
# Epoch 75/100: 100%|██████████| 32/32 [00:00<00:00, 54.60it/s, loss=0.3207]
# Epoch 75 - Average Loss: 0.3098, LR: 0.000015
# Epoch 76/100: 100%|██████████| 32/32 [00:00<00:00, 57.59it/s, loss=0.5056]
# Epoch 76 - Average Loss: 0.3215, LR: 0.000014
# Epoch 77/100: 100%|██████████| 32/32 [00:00<00:00, 55.50it/s, loss=0.2388]
# Epoch 77 - Average Loss: 0.3164, LR: 0.000012
# Epoch 78/100: 100%|██████████| 32/32 [00:00<00:00, 60.14it/s, loss=0.2139]
# Epoch 78 - Average Loss: 0.2970, LR: 0.000011
# Epoch 79/100: 100%|██████████| 32/32 [00:00<00:00, 54.21it/s, loss=0.4506]
# Epoch 79 - Average Loss: 0.3051, LR: 0.000010
# Epoch 80/100: 100%|██████████| 32/32 [00:00<00:00, 57.25it/s, loss=0.2002]
# Epoch 80 - Average Loss: 0.3050, LR: 0.000010
# Epoch 81/100: 100%|██████████| 32/32 [00:00<00:00, 54.99it/s, loss=0.2855]
# Epoch 81 - Average Loss: 0.3236, LR: 0.000009
# Epoch 82/100: 100%|██████████| 32/32 [00:00<00:00, 57.02it/s, loss=0.1639]
# Epoch 82 - Average Loss: 0.2953, LR: 0.000008
# Epoch 83/100: 100%|██████████| 32/32 [00:00<00:00, 56.63it/s, loss=0.3835]
# Epoch 83 - Average Loss: 0.3251, LR: 0.000007
# Epoch 84/100: 100%|██████████| 32/32 [00:00<00:00, 54.59it/s, loss=0.4680]
# Epoch 84 - Average Loss: 0.3187, LR: 0.000006
# Epoch 85/100: 100%|██████████| 32/32 [00:00<00:00, 58.31it/s, loss=0.2627]
# Epoch 85 - Average Loss: 0.2942, LR: 0.000005
# Epoch 86/100: 100%|██████████| 32/32 [00:00<00:00, 46.94it/s, loss=0.1594]
# Epoch 86 - Average Loss: 0.3071, LR: 0.000005
# Epoch 87/100: 100%|██████████| 32/32 [00:00<00:00, 42.08it/s, loss=0.2138]
# Epoch 87 - Average Loss: 0.2995, LR: 0.000004
# Epoch 88/100: 100%|██████████| 32/32 [00:00<00:00, 43.45it/s, loss=0.2891]
# Epoch 88 - Average Loss: 0.3200, LR: 0.000004
# Epoch 89/100: 100%|██████████| 32/32 [00:00<00:00, 38.66it/s, loss=0.1314]
# Epoch 89 - Average Loss: 0.2990, LR: 0.000003
# Epoch 90/100: 100%|██████████| 32/32 [00:00<00:00, 49.02it/s, loss=0.3784]
# Epoch 90 - Average Loss: 0.3225, LR: 0.000002
# Epoch 91/100: 100%|██████████| 32/32 [00:00<00:00, 58.08it/s, loss=0.1091]
# Epoch 91 - Average Loss: 0.3040, LR: 0.000002
# Epoch 92/100: 100%|██████████| 32/32 [00:00<00:00, 55.72it/s, loss=0.4682]
# Epoch 92 - Average Loss: 0.3414, LR: 0.000002
# Epoch 93/100: 100%|██████████| 32/32 [00:00<00:00, 57.40it/s, loss=0.3158]
# Epoch 93 - Average Loss: 0.3114, LR: 0.000001
# Epoch 94/100: 100%|██████████| 32/32 [00:00<00:00, 55.47it/s, loss=0.1591]
# Epoch 94 - Average Loss: 0.3088, LR: 0.000001
# Epoch 95/100: 100%|██████████| 32/32 [00:00<00:00, 57.69it/s, loss=0.1718]
# Epoch 95 - Average Loss: 0.2883, LR: 0.000001
# Epoch 96/100: 100%|██████████| 32/32 [00:00<00:00, 56.16it/s, loss=0.1369]
# Epoch 96 - Average Loss: 0.3117, LR: 0.000000
# Epoch 97/100: 100%|██████████| 32/32 [00:00<00:00, 56.55it/s, loss=0.1653]
# Epoch 97 - Average Loss: 0.3031, LR: 0.000000
# Epoch 98/100: 100%|██████████| 32/32 [00:00<00:00, 56.41it/s, loss=0.3694]
# Epoch 98 - Average Loss: 0.3172, LR: 0.000000
# Epoch 99/100: 100%|██████████| 32/32 [00:00<00:00, 57.49it/s, loss=0.4115]
# Epoch 99 - Average Loss: 0.3239, LR: 0.000000
# Epoch 100/100: 100%|██████████| 32/32 [00:00<00:00, 54.46it/s, loss=0.3305]
# Epoch 100 - Average Loss: 0.2995, LR: 0.000000
# Model saved to checkpoint.pth
# Generating 50 synthetic samples...
# Starting guided sampling...
# Sampling: 100%|██████████| 1000/1000 [00:02<00:00, 378.78it/s]
# Generating samples:   0%|          | 0/49 [00:00<?, ?it/s]
# Sampling...
# Generating samples:   2%|▏         | 1/49 [00:03<02:45,  3.44s/it]
# Sampling...
# Generating samples:   4%|▍         | 2/49 [00:06<02:33,  3.26s/it]
# Sampling...
# Generating samples:   6%|▌         | 3/49 [00:09<02:15,  2.94s/it]
# Sampling...
# Generating samples:   8%|▊         | 4/49 [00:11<02:06,  2.80s/it]
# Sampling...
# Generating samples:  10%|█         | 5/49 [00:14<02:06,  2.89s/it]
# Sampling...
# Generating samples:  12%|█▏        | 6/49 [00:17<02:05,  2.92s/it]
# Sampling...
# Generating samples:  14%|█▍        | 7/49 [00:20<01:58,  2.82s/it]
# Sampling...
# Generating samples:  16%|█▋        | 8/49 [00:22<01:52,  2.75s/it]
# Sampling...
# Generating samples:  18%|█▊        | 9/49 [00:25<01:48,  2.70s/it]
# Sampling...
# Generating samples:  20%|██        | 10/49 [00:28<01:53,  2.91s/it]
# Sampling...
# Generating samples:  22%|██▏       | 11/49 [00:31<01:46,  2.80s/it]
# Sampling...
# Generating samples:  24%|██▍       | 12/49 [00:34<01:40,  2.72s/it]
# Sampling...
# Generating samples:  27%|██▋       | 13/49 [00:36<01:37,  2.72s/it]
# Sampling...
# Generating samples:  29%|██▊       | 14/49 [00:39<01:38,  2.82s/it]
# Sampling...
# Generating samples:  31%|███       | 15/49 [00:42<01:36,  2.83s/it]
# Sampling...
# Generating samples:  33%|███▎      | 16/49 [00:45<01:30,  2.74s/it]
# Sampling...
# Generating samples:  35%|███▍      | 17/49 [00:47<01:25,  2.67s/it]
# Sampling...
# Generating samples:  37%|███▋      | 18/49 [00:50<01:21,  2.62s/it]
# Sampling...
# Generating samples:  39%|███▉      | 19/49 [00:53<01:25,  2.84s/it]
# Sampling...
# Generating samples:  41%|████      | 20/49 [00:56<01:20,  2.78s/it]
# Sampling...
# Generating samples:  43%|████▎     | 21/49 [00:58<01:16,  2.72s/it]
# Sampling...
# Generating samples:  45%|████▍     | 22/49 [01:01<01:11,  2.67s/it]
# Sampling...
# Generating samples:  47%|████▋     | 23/49 [01:04<01:11,  2.76s/it]
# Sampling...
# Generating samples:  49%|████▉     | 24/49 [01:07<01:10,  2.82s/it]
# Sampling...
# Generating samples:  51%|█████     | 25/49 [01:09<01:05,  2.74s/it]
# Sampling...
# Generating samples:  53%|█████▎    | 26/49 [01:12<01:01,  2.68s/it]
# Sampling...
# Generating samples:  55%|█████▌    | 27/49 [01:14<00:58,  2.66s/it]
# Sampling...
# Generating samples:  57%|█████▋    | 28/49 [01:18<01:00,  2.88s/it]
# Sampling...
# Generating samples:  59%|█████▉    | 29/49 [01:20<00:55,  2.79s/it]
# Sampling...
# Generating samples:  61%|██████    | 30/49 [01:23<00:51,  2.72s/it]
# Sampling...
# Generating samples:  63%|██████▎   | 31/49 [01:26<00:48,  2.67s/it]
# Sampling...
# Generating samples:  65%|██████▌   | 32/49 [01:29<00:47,  2.78s/it]
# Sampling...
# Generating samples:  67%|██████▋   | 33/49 [01:32<00:45,  2.83s/it]
# Sampling...
# Generating samples:  69%|██████▉   | 34/49 [01:34<00:41,  2.78s/it]
# Sampling...
# Generating samples:  71%|███████▏  | 35/49 [01:37<00:38,  2.72s/it]
# Sampling...
# Generating samples:  73%|███████▎  | 36/49 [01:39<00:34,  2.68s/it]
# Sampling...
# Generating samples:  76%|███████▌  | 37/49 [01:43<00:34,  2.91s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 38/49 [01:45<00:30,  2.80s/it]
# Sampling...
# Generating samples:  80%|███████▉  | 39/49 [01:48<00:27,  2.74s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 40/49 [01:51<00:24,  2.70s/it]
# Sampling...
# Generating samples:  84%|████████▎ | 41/49 [01:54<00:23,  2.88s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 42/49 [01:57<00:19,  2.84s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 43/49 [01:59<00:16,  2.76s/it]
# Sampling...
# Generating samples:  90%|████████▉ | 44/49 [02:02<00:13,  2.70s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 45/49 [02:04<00:10,  2.71s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 46/49 [02:08<00:08,  2.88s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 47/49 [02:10<00:05,  2.77s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 48/49 [02:13<00:02,  2.73s/it]
# Sampling...
# Generating samples: 100%|██████████| 49/49 [02:16<00:00,  2.78s/it]
# ============================================================
# VERIFICATION RESULTS (As per Table I and II in the paper)
# ============================================================
#
# 1. Statistical Similarity (Wasserstein Distance):
#    Wasserstein distance: 4.4540
#
# 2. Constraint Satisfaction (Power Flow Residuals):
#    Synthetic mean mismatch: 12.509280 ± 0.138676
#    Ground truth mean mismatch: 12.508062 ± 0.106577
# 3. Visualizing statistical similarity...
#    Creating bus-level distribution plots for five buses...
# /tmp/ipython-input-47696701.py:627: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-47696701.py:627: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-47696701.py:627: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-47696701.py:627: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
#    Creating joint density plots...
# /tmp/ipython-input-47696701.py:655: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# 4. Downstream ML Task: Warm-Start Prediction Test
#    Training baseline (Ground Truth)...
#    Training on constrained synthetic data...
#    MSE using Ground Truth: 0.010256
#    MSE using Synthetic Data: 0.029512
#
# ===========================================================
# EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY
# ===========================================================

# %%
# Corrected Implementation of "Constrained Diffusion Models for Synthesizing Representative Power Flow Datasets"
# Based on Hoseinpour & Dvorkin (2024)

# 1. Installs
# !pip install torch torchvision torchaudio --quiet
# !pip install pandapower tqdm matplotlib scipy numpy pandas seaborn --quiet
# !pip install scikit-learn --quiet

# 2. Imports and Setup
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandapower as pp
import pandapower.networks as pn
import math
import os
import copy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import euclidean_distances

# 3. Configuration
CONFIG = {
    "system": "case5",
    "num_samples": 2000,  # Increased for better training
    "num_synthetic_samples": 50,  # Number of samples to generate for comparison
    "diffusion_steps": 1000,  # Matched to paper
    "beta_start": 1e-4,
    "beta_end": 0.02,
    "hidden_dim": 256,
    "depth": 5,
    "batch_size": 64,
    "epochs": 100,  # Increased for better convergence
    "lr": 1e-4,
    "lambda_guidance": 0.01,  # Adjusted to paper's range (10^-4 to 10^-2)
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "seed": 42,
}

# 4. Model and Utility Definitions
class SinusoidalTimeEmbedding(nn.Module):
    """Sinusoidal positional encoding for time steps"""
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, t):
        device = t.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = t[:, None] * emb[None, :]
        return torch.cat((torch.sin(emb), torch.cos(emb)), dim=-1)

class DenoiserMLP(nn.Module):
    """Denoiser neural network ε_θ as described in the paper"""
    def __init__(self, dim_in, hidden=256, depth=3, time_embed_dim=128):
        super().__init__()
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)

        layers = []
        for i in range(depth):
            in_dim = dim_in + time_embed_dim if i == 0 else hidden
            out_dim = hidden if i < depth - 1 else dim_in
            layers.append(nn.Linear(in_dim, out_dim))
            if i < depth - 1:
                layers.append(nn.SiLU())  # Using SiLU (Swish) activation
                layers.append(nn.LayerNorm(out_dim))

        self.net = nn.Sequential(*layers)

        # Initialize weights
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_normal_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x, t):
        t_emb = self.time_embed(t.float())
        h = torch.cat([x, t_emb], dim=-1)
        return self.net(h)

class MinMaxNorm:
    """Min-max normalization to [-1, 1] range as per Section V-B of the paper"""
    def __init__(self, xmin, xmax, eps=1e-8):
        self.xmin = xmin.clone().detach() if isinstance(xmin, torch.Tensor) else torch.tensor(xmin, dtype=torch.float32)
        self.xmax = xmax.clone().detach() if isinstance(xmax, torch.Tensor) else torch.tensor(xmax, dtype=torch.float32)
        self.eps = eps
        self.range = torch.clamp(self.xmax - self.xmin, min=eps)

    def norm(self, x):
        """Normalize to [-1, 1] using equation (30)"""
        return 2 * (x - self.xmin.to(x.device)) / self.range.to(x.device) - 1

    def denorm(self, x):
        """Denormalize using equation (31)"""
        return ((x + 1) / 2) * self.range.to(x.device) + self.xmin.to(x.device)

    def scale_gradient(self, grad):
        """Scale gradient according to equation (32)"""
        return grad * 2 / self.range.to(grad.device)

def make_beta_schedule(T, beta_start=1e-4, beta_end=0.02, schedule='linear'):
    """Create noise schedule as described in Section III-A"""
    if schedule == 'linear':
        betas = torch.linspace(beta_start, beta_end, T)
    elif schedule == 'cosine':
        # Alternative cosine schedule
        s = 0.008
        steps = T + 1
        x = torch.linspace(0, T, steps)
        alphas_cumprod = torch.cos(((x / T) + s) / (1 + s) * torch.pi * 0.5) ** 2
        alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
        betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
        betas = torch.clip(betas, beta_start, beta_end)

    alphas = 1.0 - betas
    alpha_bar = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bar

def power_flow_residual(x_phys, G, B):
    """
    Compute power flow residual based on Equations (8a) and (8b) from the paper.
    This is the correct formulation using power balance equations.
    """
    Bdim = G.shape[0]
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    batch_size = x_phys.shape[0]
    device = x_phys.device

    # Ensure G and B are tensors on the correct device
    if not isinstance(G, torch.Tensor):
        G = torch.tensor(G, dtype=torch.float32, device=device)
    if not isinstance(B, torch.Tensor):
        B = torch.tensor(B, dtype=torch.float32, device=device)

    # Expand dimensions for broadcasting
    v_i = v.unsqueeze(2)  # [batch, Bdim, 1]
    v_j = v.unsqueeze(1)  # [batch, 1, Bdim]
    theta_i = theta.unsqueeze(2)  # [batch, Bdim, 1]
    theta_j = theta.unsqueeze(1)  # [batch, 1, Bdim]

    # Calculate angle differences
    theta_diff = theta_i - theta_j  # [batch, Bdim, Bdim]

    # Power flow equations from the paper
    # P_i = Σ_j v_i * v_j * (G_ij * cos(θ_i - θ_j) + B_ij * sin(θ_i - θ_j))
    P_calc = torch.sum(v_i * v_j * (G * torch.cos(theta_diff) + B * torch.sin(theta_diff)), dim=2)

    # Q_i = Σ_j v_i * v_j * (G_ij * sin(θ_i - θ_j) - B_ij * cos(θ_i - θ_j))
    Q_calc = torch.sum(v_i * v_j * (G * torch.sin(theta_diff) - B * torch.cos(theta_diff)), dim=2)

    # Residuals (power balance mismatch)
    p_residual = p - P_calc
    q_residual = q - Q_calc

    return torch.cat([p_residual, q_residual], dim=-1)

def compute_inequality_violations(x_phys, net):
    """Compute violations of inequality constraints (10a-10d)"""
    Bdim = len(net.bus)
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    violations = []

    # Voltage limits (10c)
    v_min = torch.tensor(net.bus.min_vm_pu.values, device=x_phys.device)
    v_max = torch.tensor(net.bus.max_vm_pu.values, device=x_phys.device)
    violations.append(torch.relu(v_min - v))  # v >= v_min
    violations.append(torch.relu(v - v_max))  # v <= v_max

    return torch.cat(violations, dim=-1)

def make_dataset(net_fn, N=500, scale_range=(0.8, 1.0), seed=0):
    """Generate ground truth dataset by solving AC-OPF as described in Section VI-A"""
    np.random.seed(seed)
    torch.manual_seed(seed)

    net = net_fn()
    base_loads_p = net.load["p_mw"].copy()
    base_loads_q = net.load["q_mvar"].copy()

    samples = []
    print(f"Generating {N} samples...")

    pbar = tqdm(range(N), desc="Generating Data")
    for _ in pbar:
        net_temp = copy.deepcopy(net)

        # Sample load scaling factors uniformly as in the paper
        scale_p = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))
        scale_q = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))

        net_temp.load["p_mw"] = base_loads_p * scale_p
        net_temp.load["q_mvar"] = base_loads_q * scale_q

        try:
            # Run power flow (not OPF for simplicity in this implementation)
            pp.runpp(net_temp, algorithm='nr', init='dc', numba=False, max_iteration=50)

            if net_temp.converged:
                # Extract power injections and voltages
                p = net_temp.res_bus.p_mw.values
                q = net_temp.res_bus.q_mvar.values
                v = net_temp.res_bus.vm_pu.values
                theta = np.deg2rad(net_temp.res_bus.va_degree.values)

                # Stack into single vector
                sample = np.concatenate([p, q, v, theta])
                samples.append(sample)
                pbar.set_postfix({"collected": len(samples)})

        except Exception as e:
            continue

    print(f"Successfully generated {len(samples)} samples.")
    return torch.tensor(np.array(samples), dtype=torch.float32)

def train_model(data, B, config):
    """Train diffusion model with variable decoupling (Algorithm 4)"""
    device = config["device"]
    T = config["diffusion_steps"]

    # Create noise schedule
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Initialize denoiser networks for variable decoupling
    den1 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)

    # Normalization
    data_min = data.min(0).values
    data_max = data.max(0).values

    # Add small noise to constant columns
    data_range = data_max - data_min
    constant_mask = data_range < 1e-6
    if constant_mask.any():
        print(f"Warning: Found {constant_mask.sum().item()} constant columns. Adding small noise.")
        data_min[constant_mask] -= 1e-4
        data_max[constant_mask] += 1e-4

    normer = MinMaxNorm(data_min, data_max)
    data_norm = normer.norm(data)

    # Check for NaN/Inf
    if torch.isnan(data_norm).any() or torch.isinf(data_norm).any():
        print("ERROR: NaN or Inf detected after normalization!")
        return None, None, None, None

    # Create dataloader
    loader = DataLoader(TensorDataset(data_norm), batch_size=config["batch_size"], shuffle=True)

    # Optimizer
    opt = torch.optim.AdamW(
        list(den1.parameters()) + list(den2.parameters()),
        lr=config["lr"],
        weight_decay=1e-5
    )

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=config["epochs"])

    loss_history = []

    print("Starting training...")
    for ep in range(config["epochs"]):
        total_loss = 0
        num_batches = 0

        pbar = tqdm(loader, desc=f"Epoch {ep+1}/{config['epochs']}")

        for (xb,) in pbar:
            xb = xb.to(device)

            # Variable decoupling: split into (p,θ) and (q,v)
            x1 = torch.cat([xb[:, :B], xb[:, 3*B:4*B]], dim=-1)  # (p, θ)
            x2 = torch.cat([xb[:, B:2*B], xb[:, 2*B:3*B]], dim=-1)  # (q, v)

            # Sample random timesteps
            t = torch.randint(0, T, (xb.size(0),), device=device)

            # Sample noise
            eps1 = torch.randn_like(x1)
            eps2 = torch.randn_like(x2)

            # Forward diffusion (equation 3)
            sqrt_ab_t = torch.sqrt(alpha_bar[t]).unsqueeze(-1)
            sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t]).unsqueeze(-1)

            x1_t = sqrt_ab_t * x1 + sqrt_1_minus_ab_t * eps1
            x2_t = sqrt_ab_t * x2 + sqrt_1_minus_ab_t * eps2

            # Predict noise
            pred1 = den1(x1_t, t)
            pred2 = den2(x2_t, t)

            # MSE loss (equation 5)
            loss1 = ((eps1 - pred1)**2).mean()
            loss2 = ((eps2 - pred2)**2).mean()
            loss = loss1 + loss2

            # Check for NaN
            if torch.isnan(loss):
                print(f"\nNaN loss detected at epoch {ep+1}!")
                break

            opt.zero_grad()
            loss.backward()

            # Gradient clipping for stability
            torch.nn.utils.clip_grad_norm_(
                list(den1.parameters()) + list(den2.parameters()),
                max_norm=1.0
            )

            opt.step()

            total_loss += loss.item()
            num_batches += 1
            pbar.set_postfix(loss=f"{loss.item():.4f}")

        scheduler.step()

        avg_loss = total_loss / num_batches
        loss_history.append(avg_loss)
        print(f"Epoch {ep+1} - Average Loss: {avg_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}")

    # Save checkpoint
    checkpoint = {
        "den1": den1.state_dict(),
        "den2": den2.state_dict(),
        "xmin": normer.xmin,
        "xmax": normer.xmax,
        "range": normer.range,
        "B": B
    }
    torch.save(checkpoint, "checkpoint.pth")
    print("Model saved to checkpoint.pth")

    return den1, den2, normer, loss_history

def sample_with_guidance(G, Bmat, config, ckpt_path="checkpoint.pth", track_residuals=False, lambda_guidance=None):
    """Sampling with manifold-constrained gradient guidance (Algorithm 5)"""
    device = config["device"]

    # Load checkpoint
    ckpt = torch.load(ckpt_path, map_location=device)
    Bdim = ckpt["B"]

    # Initialize denoisers
    den1 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den1.load_state_dict(ckpt["den1"])
    den2.load_state_dict(ckpt["den2"])
    den1.eval()
    den2.eval()

    # Normalizer
    normer = MinMaxNorm(ckpt["xmin"], ckpt["xmax"])
    if "range" in ckpt:
        normer.range = ckpt["range"]

    # Noise schedule
    T = config["diffusion_steps"]
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Guidance strength
    lam = lambda_guidance if lambda_guidance is not None else config["lambda_guidance"]

    # Initialize from pure noise
    x_t = torch.randn(1, 4 * Bdim, device=device)

    # Track residuals if requested
    residual_history = [] if track_residuals else None

    print("Starting guided sampling..." if track_residuals else "Sampling...")
    pbar = tqdm(reversed(range(T)), desc="Sampling", total=T, disable=not track_residuals)

    for t in pbar:
        # Split for variable decoupling
        x1_t = torch.cat([x_t[:, :Bdim], x_t[:, 3*Bdim:4*Bdim]], dim=-1)  # (p, θ)
        x2_t = torch.cat([x_t[:, Bdim:2*Bdim], x_t[:, 2*Bdim:3*Bdim]], dim=-1)  # (q, v)

        with torch.no_grad():
            t_tensor = torch.tensor([t], device=device)

            # Predict noise (denoisers)
            eps1 = den1(x1_t, t_tensor)
            eps2 = den2(x2_t, t_tensor)

        # Estimate clean data using Tweedie's formula (equation 6)
        sqrt_ab_t = torch.sqrt(alpha_bar[t])
        sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t])

        hat_x0_p1 = (x1_t - sqrt_1_minus_ab_t * eps1) / (sqrt_ab_t + 1e-8)
        hat_x0_p2 = (x2_t - sqrt_1_minus_ab_t * eps2) / (sqrt_ab_t + 1e-8)

        # Reconstruct full vector
        hat_x0_norm = torch.zeros(1, 4*Bdim, device=device)
        hat_x0_norm[:, :Bdim] = hat_x0_p1[:, :Bdim]  # p
        hat_x0_norm[:, Bdim:2*Bdim] = hat_x0_p2[:, :Bdim]  # q
        hat_x0_norm[:, 2*Bdim:3*Bdim] = hat_x0_p2[:, Bdim:2*Bdim]  # v
        hat_x0_norm[:, 3*Bdim:4*Bdim] = hat_x0_p1[:, Bdim:2*Bdim]  # θ

        # Clamp for stability
        hat_x0_norm = torch.clamp(hat_x0_norm, -3, 3)

        # Apply gradient guidance if lambda > 0
        if lam > 0 and t > 0:  # No guidance at t=0
            hat_x0_norm.requires_grad_(True)

            # Denormalize for physics evaluation
            x_phys = normer.denorm(hat_x0_norm)

            # Compute power flow residual
            residual = power_flow_residual(x_phys, G, Bmat)
            residual_loss = (residual**2).sum()

            if track_residuals:
                residual_history.append(torch.sqrt(residual_loss).item())

            if not torch.isnan(residual_loss):
                # Compute gradient with respect to normalized variables
                grad_norm = torch.autograd.grad(residual_loss, hat_x0_norm, create_graph=False)[0]

                # Scale gradient properly
                grad_norm = normer.scale_gradient(grad_norm)

                # Clip gradient for stability
                grad_norm = torch.clamp(grad_norm, -1.0, 1.0)

                # Apply guidance (equation 23)
                guidance_strength = lam * (1 - t/T)  # Decay guidance over time
                hat_x0_guided = hat_x0_norm - guidance_strength * grad_norm
                hat_x0_guided = hat_x0_guided.detach()
            else:
                hat_x0_guided = hat_x0_norm.detach()
        else:
            hat_x0_guided = hat_x0_norm.detach()

        # Split guided estimate for variable decoupling
        hat_x0_guided_p1 = torch.cat([hat_x0_guided[:, :Bdim], hat_x0_guided[:, 3*Bdim:4*Bdim]], dim=-1)
        hat_x0_guided_p2 = torch.cat([hat_x0_guided[:, Bdim:2*Bdim], hat_x0_guided[:, 2*Bdim:3*Bdim]], dim=-1)

        # Reverse diffusion step (equation 7)
        if t > 0:
            z = torch.randn_like(x_t)
            z1 = torch.cat([z[:, :Bdim], z[:, 3*Bdim:4*Bdim]], dim=-1)
            z2 = torch.cat([z[:, Bdim:2*Bdim], z[:, 2*Bdim:3*Bdim]], dim=-1)
        else:
            z1 = z2 = 0

        beta_t = betas[t]
        alpha_t = alphas[t]
        alpha_bar_prev = alpha_bar[t-1] if t > 0 else torch.tensor(1.0, device=device)

        # DDPM sampling coefficients
        coef1 = torch.sqrt(alpha_bar_prev) * beta_t / (1 - alpha_bar[t] + 1e-8)
        coef2 = torch.sqrt(alpha_t) * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8)
        sigma_t = torch.sqrt(beta_t * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8))

        # Update x1_t and x2_t
        x1_t = coef1 * hat_x0_guided_p1 + coef2 * x1_t + sigma_t * z1
        x2_t = coef1 * hat_x0_guided_p2 + coef2 * x2_t + sigma_t * z2

        # Reconstruct full x_t
        x_t[:, :Bdim] = x1_t[:, :Bdim]
        x_t[:, Bdim:2*Bdim] = x2_t[:, :Bdim]
        x_t[:, 2*Bdim:3*Bdim] = x2_t[:, Bdim:2*Bdim]
        x_t[:, 3*Bdim:4*Bdim] = x1_t[:, Bdim:2*Bdim]

    # Final denormalization
    final_sample = normer.denorm(x_t).cpu().numpy()

    if track_residuals:
        return final_sample, residual_history
    return final_sample

def compute_wasserstein_distance_multidim(data1, data2, seed=None):
    """ Compute multidimensional 1-Wasserstein distance (W1) between two datasets using L2 cost, as in Equation (33) of the paper.
    Assumes equal sample sizes; subsample if needed. """
    # Check dimensionality compatibility
    if data1.shape[1] != data2.shape[1]:
        raise ValueError("Data dimensions must match")

    # Subsample to min size if unequal, with optional seed for reproducibility
    min_size = min(data1.shape[0], data2.shape[0])
    if seed is not None:
        np.random.seed(seed)
    if data1.shape[0] > min_size:
        data1 = data1[np.random.choice(data1.shape[0], min_size, replace=False)]
    if data2.shape[0] > min_size:
        data2 = data2[np.random.choice(data2.shape[0], min_size, replace=False)]

    # Compute L2 cost matrix: C_ij = ||data1[i] - data2[j]||_2
    cost_matrix = euclidean_distances(data1, data2)

    # Solve optimal assignment (Hungarian algorithm)
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # W1 = (1 / N) * sum of assigned costs
    w1_distance = cost_matrix[row_ind, col_ind].sum() / min_size

    return w1_distance

# 5. Main Execution with Verification
if __name__ == "__main__":
    torch.manual_seed(CONFIG['seed'])
    np.random.seed(CONFIG['seed'])

    # Load network
    network_function = getattr(pn, CONFIG['system'])
    net = network_function()
    num_buses = len(net.bus)
    print(f"Using {CONFIG['system']} with {num_buses} buses")

    # Get admittance matrix
    pp.runpp(net)
    Ybus = net._ppc['internal']['Ybus']
    G_matrix, B_matrix = Ybus.real.toarray(), Ybus.imag.toarray()

    # Generate ground truth dataset
    dataset = make_dataset(network_function, N=CONFIG['num_samples'], seed=CONFIG['seed'])

    if len(dataset) > 0:
        print(f"\nDataset shape: {dataset.shape}")
        print(f"Dataset stats:")
        print(f"  P range: [{dataset[:, :num_buses].min():.2f}, {dataset[:, :num_buses].max():.2f}] MW")
        print(f"  Q range: [{dataset[:, num_buses:2*num_buses].min():.2f}, {dataset[:, num_buses:2*num_buses].max():.2f}] MVAr")
        print(f"  V range: [{dataset[:, 2*num_buses:3*num_buses].min():.3f}, {dataset[:, 2*num_buses:3*num_buses].max():.3f}] p.u.")
        print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")

        # Check ground truth feasibility
        print("\nChecking ground truth feasibility...")
        gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
        gt_residuals = power_flow_residual(gt_tensor, G_matrix, B_matrix)
        gt_mismatch = torch.sqrt((gt_residuals**2).mean(dim=1))
        print(f"Ground truth power mismatch (first 10): {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

        # Train the diffusion model
        den1, den2, normer, loss_history = train_model(dataset, num_buses, CONFIG)

        if den1 is not None:
            # Plot training loss
            plt.figure(figsize=(6, 4))
            plt.plot(range(1, len(loss_history) + 1), loss_history, linewidth=2)
            plt.xlabel("Epoch")
            plt.ylabel("Average Loss")
            plt.title("Training Loss over Epochs")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # Generate constrained synthetic samples
            print(f"\nGenerating {CONFIG['num_synthetic_samples']} constrained synthetic samples...")
            synthetic_samples_con = []

            # First sample with residual tracking
            first_sample, residual_history = sample_with_guidance(
                G_matrix, B_matrix, CONFIG, track_residuals=True
            )
            synthetic_samples_con.append(first_sample[0])

            # Generate remaining samples
            for i in tqdm(range(1, CONFIG['num_synthetic_samples']), desc="Generating constrained samples"):
                sample = sample_with_guidance(G_matrix, B_matrix, CONFIG, track_residuals=False)
                synthetic_samples_con.append(sample[0])

            synthetic_data_con = np.array(synthetic_samples_con)

            # Generate unconstrained synthetic samples (lambda=0)
            print(f"\nGenerating {CONFIG['num_synthetic_samples']} unconstrained synthetic samples...")
            synthetic_samples_uncon = []

            # First sample with residual tracking (unconstrained)
            first_sample_uncon, residual_history_uncon = sample_with_guidance(
                G_matrix, B_matrix, CONFIG, track_residuals=True, lambda_guidance=0
            )
            synthetic_samples_uncon.append(first_sample_uncon[0])

            # Generate remaining samples
            for i in tqdm(range(1, CONFIG['num_synthetic_samples']), desc="Generating unconstrained samples"):
                sample = sample_with_guidance(G_matrix, B_matrix, CONFIG, track_residuals=False, lambda_guidance=0)
                synthetic_samples_uncon.append(sample[0])

            synthetic_data_uncon = np.array(synthetic_samples_uncon)

            ground_truth_data = dataset.numpy()

            # Verification Results
            print("\n" + "="*60)
            print("VERIFICATION RESULTS (As per Table I and II in the paper)")
            print("="*60)

            # 1. Wasserstein Distance (Table I)
            print("\n1. Statistical Similarity (Wasserstein Distance):")
            subset_size = min(1000, len(ground_truth_data), len(synthetic_data_con), len(synthetic_data_uncon))
            w_distance_con = compute_wasserstein_distance_multidim(
                ground_truth_data[:subset_size],
                synthetic_data_con[:subset_size]
            )
            w_distance_uncon = compute_wasserstein_distance_multidim(
                ground_truth_data[:subset_size],
                synthetic_data_uncon[:subset_size]
            )
            print(f"   Wasserstein distance (constrained): {w_distance_con:.4f}")
            print(f"   Wasserstein distance (unconstrained): {w_distance_uncon:.4f}")

            # ==============================================================
            # 2. Constraint Satisfaction (Section VI-C)
            # ==============================================================
            print("\n2. Constraint Satisfaction (Power Flow Residuals):")
            synth_tensor_con = torch.tensor(synthetic_data_con, dtype=torch.float32)
            synth_residuals_con = power_flow_residual(synth_tensor_con, G_matrix, B_matrix)
            synth_mismatch_con = torch.sqrt((synth_residuals_con ** 2).mean(dim=1))
            print(f"   Constrained synthetic mean mismatch: {synth_mismatch_con.mean():.6f} ± {synth_mismatch_con.std():.6f}")

            synth_tensor_uncon = torch.tensor(synthetic_data_uncon, dtype=torch.float32)
            synth_residuals_uncon = power_flow_residual(synth_tensor_uncon, G_matrix, B_matrix)
            synth_mismatch_uncon = torch.sqrt((synth_residuals_uncon ** 2).mean(dim=1))
            print(f"   Unconstrained synthetic mean mismatch: {synth_mismatch_uncon.mean():.6f} ± {synth_mismatch_uncon.std():.6f}")

            print(f"   Ground truth mean mismatch: {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

            # Plot residual convergence history
            plt.figure(figsize=(6, 4))
            plt.plot(residual_history, linewidth=2, label="Constrained")
            plt.plot(residual_history_uncon, linewidth=2, label="Unconstrained")
            plt.xlabel("Diffusion step (t)")
            plt.ylabel("Residual norm ||H(x)||₂")
            plt.title("Residual Convergence During Guided Sampling")
            plt.grid(True, alpha=0.4)
            plt.legend()
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 3. Visual Comparison (Section VI-B figures)
            # ==============================================================
            print("\n3. Visualizing statistical similarity...")

            var_names = ['P (MW)', 'Q (MVAr)', 'V (p.u.)', 'θ (rad)']
            num_buses = G_matrix.shape[0]
            fig, axs = plt.subplots(4, 1, figsize=(8, 10))
            for i in range(4):
                start = i * num_buses
                end = (i + 1) * num_buses
                sns.kdeplot(dataset[:, start:end].flatten(), label="Ground Truth", ax=axs[i])
                sns.kdeplot(synthetic_data_con[:, start:end].flatten(), label="Syn. constrained", ax=axs[i])
                sns.kdeplot(synthetic_data_uncon[:, start:end].flatten(), label="Syn. unconstrained", ax=axs[i])
                axs[i].set_title(var_names[i])
                axs[i].legend()
            plt.tight_layout()
            plt.show()

            # Additional plots for P, Q, V, θ for five randomly selected buses
            print("   Creating bus-level distribution plots for five buses...")
            np.random.seed(CONFIG['seed'])  # Ensure reproducibility
            selected_buses = np.arange(num_buses)  # For case5, all 5 buses
            fig, axs = plt.subplots(5, 4, figsize=(16, 12), sharex='col')
            for row, bus_idx in enumerate(selected_buses):
                # Plot P, Q, V, θ for each selected bus
                for col, (var_name, offset) in enumerate(zip(var_names, [0, num_buses, 2*num_buses, 3*num_buses])):
                    idx = offset + bus_idx
                    sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
                    sns.kdeplot(synthetic_data_con[:, idx], label="Syn. constrained", ax=axs[row, col])
                    sns.kdeplot(synthetic_data_uncon[:, idx], label="Syn. unconstrained", ax=axs[row, col])
                    if row == 0:
                        axs[row, col].set_title(f"{var_name}")
                    if col == 0:
                        axs[row, col].set_ylabel(f"Bus {bus_idx+1}")
                    if row == 4:
                        axs[row, col].set_xlabel(var_name.split(' ')[0])
                    axs[row, col].legend()
            plt.suptitle("Bus-Level Distributions for P, Q, V, θ", fontsize=16)
            plt.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()

            # Joint scatter plots like in Fig. 5 of the paper
            print("   Creating joint density plots...")
            base_kv = net.bus.vn_kv.values  # Base voltages for each bus
            fig, axs = plt.subplots(2, num_buses, figsize=(3*num_buses, 6), sharey='row')
            for bus in range(num_buses):
                # Top row: q vs p (MVAr vs MW)
                sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
                            fill=True, cmap="Blues", alpha=0.5, ax=axs[0, bus])
                sns.scatterplot(x=synthetic_data_con[:, bus], y=synthetic_data_con[:, num_buses + bus],
                                color="magenta", alpha=0.3, label="Syn. constrained", ax=axs[0, bus])
                sns.scatterplot(x=synthetic_data_uncon[:, bus], y=synthetic_data_uncon[:, num_buses + bus],
                                color="green", alpha=0.3, label="Syn. unconstrained", ax=axs[0, bus])
                axs[0, bus].set_xlabel(f"p_{bus+1} (MW)")
                axs[0, bus].set_ylabel(f"q_{bus+1} (MVAr)" if bus == 0 else "")
                axs[0, bus].legend()

                # Bottom row: theta (rad) vs v (kV)
                v_gt_kv = ground_truth_data[:, 2*num_buses + bus] * base_kv[bus]
                theta_gt = ground_truth_data[:, 3*num_buses + bus]
                v_con_kv = synthetic_data_con[:, 2*num_buses + bus] * base_kv[bus]
                theta_con = synthetic_data_con[:, 3*num_buses + bus]
                v_uncon_kv = synthetic_data_uncon[:, 2*num_buses + bus] * base_kv[bus]
                theta_uncon = synthetic_data_uncon[:, 3*num_buses + bus]
                sns.kdeplot(x=v_gt_kv, y=theta_gt,
                            fill=True, cmap="Greens", alpha=0.5, ax=axs[1, bus])
                sns.scatterplot(x=v_con_kv, y=theta_con,
                                color="magenta", alpha=0.3, label="Syn. constrained", ax=axs[1, bus])
                sns.scatterplot(x=v_uncon_kv, y=theta_uncon,
                                color="green", alpha=0.3, label="Syn. unconstrained", ax=axs[1, bus])
                axs[1, bus].set_xlabel(f"v_{bus+1} (kV)")
                axs[1, bus].set_ylabel(f"θ_{bus+1} (rad)" if bus == 0 else "")
                axs[1, bus].legend()

            # Add colorbar for density
            fig.subplots_adjust(right=0.85)
            cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
            plt.colorbar(axs[0,0].collections[0], cax=cbar_ax, label="Density")
            plt.suptitle("Joint Distributions: Top - q vs p, Bottom - θ vs v")
            plt.tight_layout(rect=[0, 0, 0.85, 1])
            plt.show()

            # Joint scatter plots (P vs Q, V vs θ) for bus 0 as in original code
            print("   Creating joint density plots...")
            plt.figure(figsize=(10, 4))
            plt.subplot(1, 2, 1)
            sns.kdeplot(
                x=dataset[:, 0], y=dataset[:, num_buses],
                fill=True, cmap="Blues", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data_con[:, 0], y=synthetic_data_con[:, num_buses],
                color="magenta", alpha=0.3, label="Syn. constrained"
            )
            sns.scatterplot(
                x=synthetic_data_uncon[:, 0], y=synthetic_data_uncon[:, num_buses],
                color="green", alpha=0.3, label="Syn. unconstrained"
            )
            plt.title("Joint Distribution: P vs Q")
            plt.legend()

            plt.subplot(1, 2, 2)
            sns.kdeplot(
                x=dataset[:, 2*num_buses], y=dataset[:, 3*num_buses],
                fill=True, cmap="Greens", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data_con[:, 2*num_buses], y=synthetic_data_con[:, 3*num_buses],
                color="magenta", alpha=0.3, label="Syn. constrained"
            )
            sns.scatterplot(
                x=synthetic_data_uncon[:, 2*num_buses], y=synthetic_data_uncon[:, 3*num_buses],
                color="green", alpha=0.3, label="Syn. unconstrained"
            )
            plt.title("Joint Distribution: V vs θ")
            plt.legend()
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 4. Utility in Downstream ML Task (Section VI-D)
            # ==============================================================
            print("\n4. Downstream ML Task: Warm-Start Prediction Test")

            import sklearn.model_selection as skms
            import sklearn.neural_network as sknn
            from sklearn.metrics import mean_squared_error

            # Create simple supervised learning task
            # Here we try to learn mapping from (p,q) → (v,θ)
            X_gt = dataset[:, :2*num_buses].numpy()
            y_gt = dataset[:, 2*num_buses:].numpy()

            X_con = synthetic_data_con[:, :2*num_buses]
            y_con = synthetic_data_con[:, 2*num_buses:]

            X_uncon = synthetic_data_uncon[:, :2*num_buses]
            y_uncon = synthetic_data_uncon[:, 2*num_buses:]

            # Train-test split
            X_train_gt, X_test_gt, y_train_gt, y_test_gt = skms.train_test_split(X_gt, y_gt, test_size=0.3, random_state=CONFIG['seed'])
            X_train_con, X_test_con, y_train_con, y_test_con = skms.train_test_split(X_con, y_con, test_size=0.3, random_state=CONFIG['seed'])
            X_train_uncon, X_test_uncon, y_train_uncon, y_test_uncon = skms.train_test_split(X_uncon, y_uncon, test_size=0.3, random_state=CONFIG['seed'])

            # MLP regressor
            def train_mlp(X_train, y_train):
                mlp = sknn.MLPRegressor(hidden_layer_sizes=(128, 128),
                                         activation='relu',
                                         solver='adam',
                                         max_iter=500,
                                         random_state=CONFIG['seed'])
                mlp.fit(X_train, y_train)
                return mlp

            print("   Training baseline (Ground Truth)...")
            mlp_gt = train_mlp(X_train_gt, y_train_gt)
            print("   Training on constrained synthetic data...")
            mlp_con = train_mlp(X_train_con, y_train_con)
            print("   Training on unconstrained synthetic data...")
            mlp_uncon = train_mlp(X_train_uncon, y_train_uncon)

            # Evaluate
            y_pred_gt = mlp_gt.predict(X_test_gt)
            y_pred_con = mlp_con.predict(X_test_gt)
            y_pred_uncon = mlp_uncon.predict(X_test_gt)

            mse_gt = mean_squared_error(y_test_gt, y_pred_gt)
            mse_con = mean_squared_error(y_test_gt, y_pred_con)
            mse_uncon = mean_squared_error(y_test_gt, y_pred_uncon)

            print(f"   MSE using Ground Truth: {mse_gt:.6f}")
            print(f"   MSE using Constrained Synthetic Data: {mse_con:.6f}")
            print(f"   MSE using Unconstrained Synthetic Data: {mse_uncon:.6f}")
            print("\n===========================================================")
            print("EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY")
            print("===========================================================")

        else:
            print("Dataset generation failed or returned no samples.")
    else:
        print("Dataset generation failed. Check pandapower installation or seed.")
# Out:
# Using case5 with 5 buses
# Generating 2000 samples...
# Generating Data: 100%|██████████| 2000/2000 [02:00<00:00, 16.61it/s, collected=2000]
# /tmp/ipython-input-679920764.py:545: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")
# /tmp/ipython-input-679920764.py:549: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
# Successfully generated 2000 samples.
#
# Dataset shape: torch.Size([2000, 20])
# Dataset stats:
#   P range: [-466.51, 512.24] MW
#   Q range: [-95.06, 98.60] MVAr
#   V range: [0.989, 1.000] p.u.
#   θ range: [-0.7, 4.5] degrees
#
# Checking ground truth feasibility...
# Ground truth power mismatch (first 10): 240.118607 ± 4.374482
# Warning: Found 7 constant columns. Adding small noise.
# Starting training...
# Epoch 1/100: 100%|██████████| 32/32 [00:00<00:00, 60.08it/s, loss=1.7545]
# Epoch 1 - Average Loss: 3.2260, LR: 0.000100
# Epoch 2/100: 100%|██████████| 32/32 [00:00<00:00, 58.72it/s, loss=1.1244]
# Epoch 2 - Average Loss: 1.4849, LR: 0.000100
# Epoch 3/100: 100%|██████████| 32/32 [00:00<00:00, 58.76it/s, loss=1.0315]
# Epoch 3 - Average Loss: 0.9480, LR: 0.000100
# Epoch 4/100: 100%|██████████| 32/32 [00:00<00:00, 61.03it/s, loss=0.6957]
# Epoch 4 - Average Loss: 0.7048, LR: 0.000100
# Epoch 5/100: 100%|██████████| 32/32 [00:00<00:00, 59.06it/s, loss=0.6765]
# Epoch 5 - Average Loss: 0.5507, LR: 0.000099
# Epoch 6/100: 100%|██████████| 32/32 [00:00<00:00, 61.35it/s, loss=0.3562]
# Epoch 6 - Average Loss: 0.4776, LR: 0.000099
# Epoch 7/100: 100%|██████████| 32/32 [00:00<00:00, 57.39it/s, loss=0.2086]
# Epoch 7 - Average Loss: 0.4250, LR: 0.000099
# Epoch 8/100: 100%|██████████| 32/32 [00:00<00:00, 60.37it/s, loss=0.2932]
# Epoch 8 - Average Loss: 0.3814, LR: 0.000098
# Epoch 9/100: 100%|██████████| 32/32 [00:00<00:00, 58.63it/s, loss=0.2416]
# Epoch 9 - Average Loss: 0.3366, LR: 0.000098
# Epoch 10/100: 100%|██████████| 32/32 [00:00<00:00, 59.82it/s, loss=0.1628]
# Epoch 10 - Average Loss: 0.3166, LR: 0.000098
# Epoch 11/100: 100%|██████████| 32/32 [00:00<00:00, 59.13it/s, loss=0.3852]
# Epoch 11 - Average Loss: 0.2906, LR: 0.000097
# Epoch 12/100: 100%|██████████| 32/32 [00:00<00:00, 60.73it/s, loss=0.3171]
# Epoch 12 - Average Loss: 0.2650, LR: 0.000096
# Epoch 13/100: 100%|██████████| 32/32 [00:00<00:00, 59.88it/s, loss=0.3063]
# Epoch 13 - Average Loss: 0.2687, LR: 0.000096
# Epoch 14/100: 100%|██████████| 32/32 [00:00<00:00, 59.65it/s, loss=0.2462]
# Epoch 14 - Average Loss: 0.2649, LR: 0.000095
# Epoch 15/100: 100%|██████████| 32/32 [00:00<00:00, 58.90it/s, loss=0.2727]
# Epoch 15 - Average Loss: 0.2661, LR: 0.000095
# Epoch 16/100: 100%|██████████| 32/32 [00:00<00:00, 47.82it/s, loss=0.2956]
# Epoch 16 - Average Loss: 0.2390, LR: 0.000094
# Epoch 17/100: 100%|██████████| 32/32 [00:00<00:00, 44.42it/s, loss=0.1788]
# Epoch 17 - Average Loss: 0.2391, LR: 0.000093
# Epoch 18/100: 100%|██████████| 32/32 [00:00<00:00, 46.77it/s, loss=0.1400]
# Epoch 18 - Average Loss: 0.2382, LR: 0.000092
# Epoch 19/100: 100%|██████████| 32/32 [00:01<00:00, 21.73it/s, loss=0.1353]
# Epoch 19 - Average Loss: 0.2209, LR: 0.000091
# Epoch 20/100: 100%|██████████| 32/32 [00:00<00:00, 36.14it/s, loss=0.1936]
# Epoch 20 - Average Loss: 0.2210, LR: 0.000090
# Epoch 21/100: 100%|██████████| 32/32 [00:01<00:00, 31.39it/s, loss=0.0780]
# Epoch 21 - Average Loss: 0.2061, LR: 0.000090
# Epoch 22/100: 100%|██████████| 32/32 [00:00<00:00, 32.99it/s, loss=0.0993]
# Epoch 22 - Average Loss: 0.1965, LR: 0.000089
# Epoch 23/100: 100%|██████████| 32/32 [00:00<00:00, 32.26it/s, loss=0.3353]
# Epoch 23 - Average Loss: 0.2041, LR: 0.000088
# Epoch 24/100: 100%|██████████| 32/32 [00:00<00:00, 33.12it/s, loss=0.1706]
# Epoch 24 - Average Loss: 0.1964, LR: 0.000086
# Epoch 25/100: 100%|██████████| 32/32 [00:00<00:00, 41.74it/s, loss=0.2801]
# Epoch 25 - Average Loss: 0.2003, LR: 0.000085
# Epoch 26/100: 100%|██████████| 32/32 [00:00<00:00, 38.70it/s, loss=0.1264]
# Epoch 26 - Average Loss: 0.1984, LR: 0.000084
# Epoch 27/100: 100%|██████████| 32/32 [00:00<00:00, 42.76it/s, loss=0.2695]
# Epoch 27 - Average Loss: 0.1976, LR: 0.000083
# Epoch 28/100: 100%|██████████| 32/32 [00:00<00:00, 37.59it/s, loss=0.1689]
# Epoch 28 - Average Loss: 0.1700, LR: 0.000082
# Epoch 29/100: 100%|██████████| 32/32 [00:00<00:00, 36.52it/s, loss=0.2933]
# Epoch 29 - Average Loss: 0.1888, LR: 0.000081
# Epoch 30/100: 100%|██████████| 32/32 [00:00<00:00, 37.78it/s, loss=0.1187]
# Epoch 30 - Average Loss: 0.1805, LR: 0.000079
# Epoch 31/100: 100%|██████████| 32/32 [00:01<00:00, 26.82it/s, loss=0.1939]
# Epoch 31 - Average Loss: 0.1803, LR: 0.000078
# Epoch 32/100: 100%|██████████| 32/32 [00:01<00:00, 20.76it/s, loss=0.1623]
# Epoch 32 - Average Loss: 0.1871, LR: 0.000077
# Epoch 33/100: 100%|██████████| 32/32 [00:01<00:00, 26.50it/s, loss=0.1676]
# Epoch 33 - Average Loss: 0.1744, LR: 0.000075
# Epoch 34/100: 100%|██████████| 32/32 [00:01<00:00, 20.94it/s, loss=0.1009]
# Epoch 73/100: 100%|██████████| 32/32 [00:00<00:00, 46.37it/s, loss=0.1596]
# Epoch 73 - Average Loss: 0.1446, LR: 0.000017
# Epoch 74/100: 100%|██████████| 32/32 [00:00<00:00, 39.67it/s, loss=0.1151]
# Epoch 74 - Average Loss: 0.1436, LR: 0.000016
# Epoch 75/100: 100%|██████████| 32/32 [00:00<00:00, 57.47it/s, loss=0.1458]
# Epoch 75 - Average Loss: 0.1454, LR: 0.000015
# Epoch 76/100: 100%|██████████| 32/32 [00:00<00:00, 59.80it/s, loss=0.2432]
# Epoch 76 - Average Loss: 0.1461, LR: 0.000014
# Epoch 77/100: 100%|██████████| 32/32 [00:00<00:00, 56.68it/s, loss=0.1777]
# Epoch 77 - Average Loss: 0.1377, LR: 0.000012
# Epoch 78/100: 100%|██████████| 32/32 [00:00<00:00, 57.74it/s, loss=0.1149]
# Epoch 78 - Average Loss: 0.1408, LR: 0.000011
# Epoch 79/100: 100%|██████████| 32/32 [00:00<00:00, 57.08it/s, loss=0.1015]
# Epoch 79 - Average Loss: 0.1362, LR: 0.000010
# Epoch 80/100: 100%|██████████| 32/32 [00:00<00:00, 59.83it/s, loss=0.2779]
# Epoch 80 - Average Loss: 0.1420, LR: 0.000010
# Epoch 81/100: 100%|██████████| 32/32 [00:00<00:00, 57.96it/s, loss=0.0826]
# Epoch 81 - Average Loss: 0.1343, LR: 0.000009
# Epoch 82/100: 100%|██████████| 32/32 [00:00<00:00, 60.06it/s, loss=0.1557]
# Epoch 82 - Average Loss: 0.1395, LR: 0.000008
# Epoch 83/100: 100%|██████████| 32/32 [00:00<00:00, 58.64it/s, loss=0.1859]
# Epoch 83 - Average Loss: 0.1349, LR: 0.000007
# Epoch 84/100: 100%|██████████| 32/32 [00:00<00:00, 58.92it/s, loss=0.1006]
# Epoch 84 - Average Loss: 0.1350, LR: 0.000006
# Epoch 85/100: 100%|██████████| 32/32 [00:00<00:00, 55.92it/s, loss=0.1371]
# Epoch 85 - Average Loss: 0.1413, LR: 0.000005
# Epoch 86/100: 100%|██████████| 32/32 [00:00<00:00, 54.33it/s, loss=0.0674]
# Epoch 86 - Average Loss: 0.1320, LR: 0.000005
# Epoch 87/100: 100%|██████████| 32/32 [00:00<00:00, 54.17it/s, loss=0.0853]
# Epoch 87 - Average Loss: 0.1393, LR: 0.000004
# Epoch 88/100: 100%|██████████| 32/32 [00:00<00:00, 56.32it/s, loss=0.0734]
# Epoch 88 - Average Loss: 0.1281, LR: 0.000004
# Epoch 89/100: 100%|██████████| 32/32 [00:00<00:00, 58.33it/s, loss=0.1641]
# Epoch 89 - Average Loss: 0.1363, LR: 0.000003
# Epoch 90/100: 100%|██████████| 32/32 [00:00<00:00, 57.04it/s, loss=0.2409]
# Epoch 90 - Average Loss: 0.1470, LR: 0.000002
# Epoch 91/100: 100%|██████████| 32/32 [00:00<00:00, 55.42it/s, loss=0.1248]
# Epoch 91 - Average Loss: 0.1291, LR: 0.000002
# Epoch 92/100: 100%|██████████| 32/32 [00:00<00:00, 48.59it/s, loss=0.0860]
# Epoch 92 - Average Loss: 0.1430, LR: 0.000002
# Epoch 93/100: 100%|██████████| 32/32 [00:00<00:00, 41.83it/s, loss=0.3145]
# Epoch 93 - Average Loss: 0.1389, LR: 0.000001
# Epoch 94/100: 100%|██████████| 32/32 [00:00<00:00, 45.28it/s, loss=0.1492]
# Epoch 94 - Average Loss: 0.1324, LR: 0.000001
# Epoch 95/100: 100%|██████████| 32/32 [00:00<00:00, 40.21it/s, loss=0.0955]
# Epoch 95 - Average Loss: 0.1315, LR: 0.000001
# Epoch 96/100: 100%|██████████| 32/32 [00:00<00:00, 45.43it/s, loss=0.0782]
# Epoch 96 - Average Loss: 0.1463, LR: 0.000000
# Epoch 97/100: 100%|██████████| 32/32 [00:00<00:00, 57.05it/s, loss=0.1551]
# Epoch 97 - Average Loss: 0.1396, LR: 0.000000
# Epoch 98/100: 100%|██████████| 32/32 [00:00<00:00, 55.85it/s, loss=0.1119]
# Epoch 98 - Average Loss: 0.1451, LR: 0.000000
# Epoch 99/100: 100%|██████████| 32/32 [00:00<00:00, 57.85it/s, loss=0.3672]
# Epoch 99 - Average Loss: 0.1576, LR: 0.000000
# Epoch 100/100: 100%|██████████| 32/32 [00:00<00:00, 54.94it/s, loss=0.0560]
# Epoch 100 - Average Loss: 0.1342, LR: 0.000000
# Model saved to checkpoint.pth
# Generating 50 constrained synthetic samples...
# Starting guided sampling...
# Sampling: 100%|██████████| 1000/1000 [00:02<00:00, 367.16it/s]
# Generating constrained samples:   0%|          | 0/49 [00:00<?, ?it/s]
# Sampling...
# Generating constrained samples:   2%|▏         | 1/49 [00:02<02:00,  2.50s/it]
# Sampling...
# Generating constrained samples:   4%|▍         | 2/49 [00:05<02:11,  2.80s/it]
# Sampling...
# Generating constrained samples:   6%|▌         | 3/49 [00:08<02:12,  2.87s/it]
# Sampling...
# Generating constrained samples:   8%|▊         | 4/49 [00:11<02:04,  2.76s/it]
# Sampling...
# Generating constrained samples:  10%|█         | 5/49 [00:13<01:57,  2.68s/it]
# Sampling...
# Generating constrained samples:  12%|█▏        | 6/49 [00:16<01:52,  2.63s/it]
# Sampling...
# Generating constrained samples:  14%|█▍        | 7/49 [00:19<02:00,  2.87s/it]
# Sampling...
# Generating constrained samples:  16%|█▋        | 8/49 [00:22<01:54,  2.79s/it]
# Sampling...
# Generating constrained samples:  18%|█▊        | 9/49 [00:24<01:49,  2.73s/it]
# Sampling...
# Generating constrained samples:  20%|██        | 10/49 [00:27<01:46,  2.72s/it]
# Sampling...
# Generating constrained samples:  22%|██▏       | 11/49 [00:30<01:44,  2.76s/it]
# Sampling...
# Generating constrained samples:  24%|██▍       | 12/49 [00:33<01:46,  2.88s/it]
# Sampling...
# Generating constrained samples:  27%|██▋       | 13/49 [00:36<01:41,  2.82s/it]
# Sampling...
# Generating constrained samples:  29%|██▊       | 14/49 [00:38<01:35,  2.73s/it]
# Sampling...
# Generating constrained samples:  31%|███       | 15/49 [00:41<01:31,  2.69s/it]
# Sampling...
# Generating constrained samples:  33%|███▎      | 16/49 [00:44<01:35,  2.91s/it]
# Sampling...
# Generating constrained samples:  35%|███▍      | 17/49 [00:47<01:29,  2.80s/it]
# Sampling...
# Generating constrained samples:  37%|███▋      | 18/49 [00:49<01:24,  2.73s/it]
# Sampling...
# Generating constrained samples:  39%|███▉      | 19/49 [00:52<01:19,  2.66s/it]
# Sampling...
# Generating constrained samples:  41%|████      | 20/49 [00:55<01:18,  2.70s/it]
# Sampling...
# Generating constrained samples:  43%|████▎     | 21/49 [00:58<01:19,  2.83s/it]
# Sampling...
# Generating constrained samples:  45%|████▍     | 22/49 [01:00<01:13,  2.73s/it]
# Sampling...
# Generating constrained samples:  47%|████▋     | 23/49 [01:03<01:09,  2.66s/it]
# Sampling...
# Generating constrained samples:  49%|████▉     | 24/49 [01:06<01:11,  2.86s/it]
# Sampling...
# Generating constrained samples:  51%|█████     | 25/49 [01:09<01:12,  3.01s/it]
# Sampling...
# Generating constrained samples:  53%|█████▎    | 26/49 [01:12<01:05,  2.85s/it]
# Sampling...
# Generating constrained samples:  55%|█████▌    | 27/49 [01:14<01:00,  2.76s/it]
# Sampling...
# Generating constrained samples:  57%|█████▋    | 28/49 [01:17<00:56,  2.67s/it]
# Sampling...
# Generating constrained samples:  59%|█████▉    | 29/49 [01:20<00:54,  2.73s/it]
# Sampling...
# Generating constrained samples:  61%|██████    | 30/49 [01:23<00:54,  2.85s/it]
# Sampling...
# Generating constrained samples:  63%|██████▎   | 31/49 [01:25<00:49,  2.76s/it]
# Sampling...
# Generating constrained samples:  65%|██████▌   | 32/49 [01:28<00:46,  2.71s/it]
# Sampling...
# Generating constrained samples:  67%|██████▋   | 33/49 [01:31<00:42,  2.68s/it]
# Sampling...
# Generating constrained samples:  69%|██████▉   | 34/49 [01:34<00:43,  2.88s/it]
# Sampling...
# Generating constrained samples:  71%|███████▏  | 35/49 [01:37<00:39,  2.80s/it]
# Sampling...
# Generating constrained samples:  73%|███████▎  | 36/49 [01:39<00:36,  2.77s/it]
# Sampling...
# Generating constrained samples:  76%|███████▌  | 37/49 [01:42<00:32,  2.69s/it]
# Sampling...
# Generating constrained samples:  78%|███████▊  | 38/49 [01:45<00:30,  2.74s/it]
# Sampling...
# Generating constrained samples:  80%|███████▉  | 39/49 [01:48<00:28,  2.80s/it]
# Sampling...
# Generating constrained samples:  82%|████████▏ | 40/49 [01:50<00:24,  2.72s/it]
# Sampling...
# Generating constrained samples:  84%|████████▎ | 41/49 [01:53<00:21,  2.66s/it]
# Sampling...
# Generating constrained samples:  86%|████████▌ | 42/49 [01:55<00:18,  2.59s/it]
# Sampling...
# Generating constrained samples:  88%|████████▊ | 43/49 [01:58<00:16,  2.79s/it]
# Sampling...
# Generating constrained samples:  90%|████████▉ | 44/49 [02:01<00:13,  2.69s/it]
# Sampling...
# Generating constrained samples:  92%|█████████▏| 45/49 [02:03<00:10,  2.62s/it]
# Sampling...
# Generating constrained samples:  94%|█████████▍| 46/49 [02:06<00:07,  2.61s/it]
# Sampling...
# Generating constrained samples:  96%|█████████▌| 47/49 [02:08<00:05,  2.56s/it]
# Sampling...
# Generating constrained samples:  98%|█████████▊| 48/49 [02:12<00:02,  2.78s/it]
# Sampling...
# Generating constrained samples: 100%|██████████| 49/49 [02:14<00:00,  2.74s/it]
# Generating 50 unconstrained synthetic samples...
# Starting guided sampling...
# Sampling: 100%|██████████| 1000/1000 [00:01<00:00, 771.00it/s]
# Generating unconstrained samples:   0%|          | 0/49 [00:00<?, ?it/s]
# Sampling...
# Generating unconstrained samples:   2%|▏         | 1/49 [00:01<01:03,  1.33s/it]
# Sampling...
# Generating unconstrained samples:   4%|▍         | 2/49 [00:02<01:00,  1.28s/it]
# Sampling...
# Generating unconstrained samples:   6%|▌         | 3/49 [00:03<00:58,  1.27s/it]
# Sampling...
# Generating unconstrained samples:   8%|▊         | 4/49 [00:05<00:56,  1.26s/it]
# Sampling...
# Generating unconstrained samples:  10%|█         | 5/49 [00:06<01:02,  1.42s/it]
# Sampling...
# Generating unconstrained samples:  12%|█▏        | 6/49 [00:08<01:05,  1.52s/it]
# Sampling...
# Generating unconstrained samples:  14%|█▍        | 7/49 [00:09<01:00,  1.43s/it]
# Sampling...
# Generating unconstrained samples:  16%|█▋        | 8/49 [00:10<00:56,  1.37s/it]
# Sampling...
# Generating unconstrained samples:  18%|█▊        | 9/49 [00:12<00:55,  1.40s/it]
# Sampling...
# Generating unconstrained samples:  20%|██        | 10/49 [00:13<00:53,  1.37s/it]
# Sampling...
# Generating unconstrained samples:  22%|██▏       | 11/49 [00:15<00:51,  1.35s/it]
# Sampling...
# Generating unconstrained samples:  24%|██▍       | 12/49 [00:16<00:48,  1.31s/it]
# Sampling...
# Generating unconstrained samples:  27%|██▋       | 13/49 [00:17<00:46,  1.29s/it]
# Sampling...
# Generating unconstrained samples:  29%|██▊       | 14/49 [00:19<00:49,  1.42s/it]
# Sampling...
# Generating unconstrained samples:  31%|███       | 15/49 [00:20<00:50,  1.49s/it]
# Sampling...
# Generating unconstrained samples:  33%|███▎      | 16/49 [00:22<00:46,  1.41s/it]
# Sampling...
# Generating unconstrained samples:  35%|███▍      | 17/49 [00:23<00:44,  1.38s/it]
# Sampling...
# Generating unconstrained samples:  37%|███▋      | 18/49 [00:24<00:41,  1.34s/it]
# Sampling...
# Generating unconstrained samples:  39%|███▉      | 19/49 [00:25<00:39,  1.31s/it]
# Sampling...
# Generating unconstrained samples:  41%|████      | 20/49 [00:27<00:37,  1.30s/it]
# Sampling...
# Generating unconstrained samples:  43%|████▎     | 21/49 [00:28<00:35,  1.28s/it]
# Sampling...
# Generating unconstrained samples:  45%|████▍     | 22/49 [00:29<00:34,  1.28s/it]
# Sampling...
# Generating unconstrained samples:  47%|████▋     | 23/49 [00:31<00:35,  1.37s/it]
# Sampling...
# Generating unconstrained samples:  49%|████▉     | 24/49 [00:33<00:37,  1.49s/it]
# Sampling...
# Generating unconstrained samples:  51%|█████     | 25/49 [00:34<00:34,  1.45s/it]
# Sampling...
# Generating unconstrained samples:  53%|█████▎    | 26/49 [00:36<00:37,  1.64s/it]
# Sampling...
# Generating unconstrained samples:  55%|█████▌    | 27/49 [00:37<00:33,  1.52s/it]
# Sampling...
# Generating unconstrained samples:  57%|█████▋    | 28/49 [00:38<00:30,  1.44s/it]
# Sampling...
# Generating unconstrained samples:  59%|█████▉    | 29/49 [00:40<00:27,  1.38s/it]
# Sampling...
# Generating unconstrained samples:  61%|██████    | 30/49 [00:41<00:25,  1.34s/it]
# Sampling...
# Generating unconstrained samples:  63%|██████▎   | 31/49 [00:42<00:23,  1.32s/it]
# Sampling...
# Generating unconstrained samples:  65%|██████▌   | 32/49 [00:44<00:26,  1.54s/it]
# Sampling...
# Generating unconstrained samples:  67%|██████▋   | 33/49 [00:46<00:24,  1.51s/it]
# Sampling...
# Generating unconstrained samples:  69%|██████▉   | 34/49 [00:47<00:21,  1.44s/it]
# Sampling...
# Generating unconstrained samples:  71%|███████▏  | 35/49 [00:48<00:19,  1.37s/it]
# Sampling...
# Generating unconstrained samples:  73%|███████▎  | 36/49 [00:49<00:17,  1.33s/it]
# Sampling...
# Generating unconstrained samples:  76%|███████▌  | 37/49 [00:51<00:15,  1.31s/it]
# Sampling...
# Generating unconstrained samples:  78%|███████▊  | 38/49 [00:52<00:14,  1.29s/it]
# Sampling...
# Generating unconstrained samples:  80%|███████▉  | 39/49 [00:53<00:12,  1.28s/it]
# Sampling...
# Generating unconstrained samples:  82%|████████▏ | 40/49 [00:54<00:11,  1.27s/it]
# Sampling...
# Generating unconstrained samples:  84%|████████▎ | 41/49 [00:56<00:11,  1.40s/it]
# Sampling...
# Generating unconstrained samples:  86%|████████▌ | 42/49 [00:58<00:10,  1.49s/it]
# Sampling...
# Generating unconstrained samples:  88%|████████▊ | 43/49 [00:59<00:08,  1.41s/it]
# Sampling...
# Generating unconstrained samples:  90%|████████▉ | 44/49 [01:00<00:06,  1.38s/it]
# Sampling...
# Generating unconstrained samples:  92%|█████████▏| 45/49 [01:02<00:05,  1.35s/it]
# Sampling...
# Generating unconstrained samples:  94%|█████████▍| 46/49 [01:03<00:04,  1.33s/it]
# Sampling...
# Generating unconstrained samples:  96%|█████████▌| 47/49 [01:04<00:02,  1.31s/it]
# Sampling...
# Generating unconstrained samples:  98%|█████████▊| 48/49 [01:06<00:01,  1.32s/it]
# Sampling...
# Generating unconstrained samples: 100%|██████████| 49/49 [01:07<00:00,  1.37s/it]
# ============================================================
# VERIFICATION RESULTS (As per Table I and II in the paper)
# ============================================================
#
# 1. Statistical Similarity (Wasserstein Distance):
#    Wasserstein distance (constrained): 15.9816
#    Wasserstein distance (unconstrained): 16.2070
#
# 2. Constraint Satisfaction (Power Flow Residuals):
#    Constrained synthetic mean mismatch: 240.126678 ± 3.627385
#    Unconstrained synthetic mean mismatch: 240.164886 ± 4.157614
#    Ground truth mean mismatch: 240.118607 ± 4.374482
# 3. Visualizing statistical similarity...
#    Creating bus-level distribution plots for five buses...
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:680: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(synthetic_data_con[:, idx], label="Syn. constrained", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:681: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(synthetic_data_uncon[:, idx], label="Syn. unconstrained", ax=axs[row, col])
# /tmp/ipython-input-679920764.py:688: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   axs[row, col].legend()
# /tmp/ipython-input-679920764.py:679: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
#    Creating joint density plots...
# /tmp/ipython-input-679920764.py:699: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
# /tmp/ipython-input-679920764.py:716: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=v_gt_kv, y=theta_gt,
# /tmp/ipython-input-679920764.py:716: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=v_gt_kv, y=theta_gt,
# /tmp/ipython-input-679920764.py:716: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=v_gt_kv, y=theta_gt,
# /tmp/ipython-input-679920764.py:699: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
# /tmp/ipython-input-679920764.py:716: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=v_gt_kv, y=theta_gt,
# /tmp/ipython-input-679920764.py:731: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.85, 1])
#    Creating joint density plots...
# /tmp/ipython-input-679920764.py:738: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# /tmp/ipython-input-679920764.py:754: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# 4. Downstream ML Task: Warm-Start Prediction Test
#    Training baseline (Ground Truth)...
#    Training on constrained synthetic data...
#    Training on unconstrained synthetic data...
#    MSE using Ground Truth: 0.002166
#    MSE using Constrained Synthetic Data: 144.262894
#    MSE using Unconstrained Synthetic Data: 138.457275
#
# ===========================================================
# EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY
# ===========================================================

# %%
# Corrected Implementation of "Constrained Diffusion Models for Synthesizing Representative Power Flow Datasets"
# Based on Hoseinpour & Dvorkin (2024)

# 1. Installs
# !pip install torch torchvision torchaudio --quiet
# !pip install pandapower tqdm matplotlib scipy numpy pandas seaborn --quiet
# !pip install scikit-learn --quiet

# 2. Imports and Setup
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset
import numpy as np
import pandapower as pp
import pandapower.networks as pn
import math
import os
import copy
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
from scipy.optimize import linear_sum_assignment
from sklearn.metrics.pairwise import euclidean_distances

# 3. Configuration
CONFIG = {
    "system": "case30",
    "num_samples": 5000,  # Increased for better training
    "num_synthetic_samples": 500,  # Number of samples to generate for comparison
    "diffusion_steps": 1000,  # Matched to paper
    "beta_start": 1e-4,
    "beta_end": 0.02,
    "hidden_dim": 256,
    "depth": 5,
    "batch_size": 64,
    "epochs": 500,  # Increased for better convergence
    "lr": 1e-4,
    "lambda_guidance": 0.01,  # Adjusted to paper's range (10^-4 to 10^-2)
    "device": "cuda" if torch.cuda.is_available() else "cpu",
    "seed": 42,
}

# 4. Model and Utility Definitions
class SinusoidalTimeEmbedding(nn.Module):
    """Sinusoidal positional encoding for time steps"""
    def __init__(self, dim):
        super().__init__()
        self.dim = dim

    def forward(self, t):
        device = t.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = t[:, None] * emb[None, :]
        return torch.cat((torch.sin(emb), torch.cos(emb)), dim=-1)

class DenoiserMLP(nn.Module):
    """Denoiser neural network ε_θ as described in the paper"""
    def __init__(self, dim_in, hidden=256, depth=3, time_embed_dim=128):
        super().__init__()
        self.time_embed = SinusoidalTimeEmbedding(time_embed_dim)

        layers = []
        for i in range(depth):
            in_dim = dim_in + time_embed_dim if i == 0 else hidden
            out_dim = hidden if i < depth - 1 else dim_in
            layers.append(nn.Linear(in_dim, out_dim))
            if i < depth - 1:
                layers.append(nn.SiLU())  # Using SiLU (Swish) activation
                layers.append(nn.LayerNorm(out_dim))

        self.net = nn.Sequential(*layers)

        # Initialize weights
        for layer in self.net:
            if isinstance(layer, nn.Linear):
                nn.init.xavier_normal_(layer.weight)
                nn.init.zeros_(layer.bias)

    def forward(self, x, t):
        t_emb = self.time_embed(t.float())
        h = torch.cat([x, t_emb], dim=-1)
        return self.net(h)

class MinMaxNorm:
    """Min-max normalization to [-1, 1] range as per Section V-B of the paper"""
    def __init__(self, xmin, xmax, eps=1e-8):
        self.xmin = xmin.clone().detach() if isinstance(xmin, torch.Tensor) else torch.tensor(xmin, dtype=torch.float32)
        self.xmax = xmax.clone().detach() if isinstance(xmax, torch.Tensor) else torch.tensor(xmax, dtype=torch.float32)
        self.eps = eps
        self.range = torch.clamp(self.xmax - self.xmin, min=eps)

    def norm(self, x):
        """Normalize to [-1, 1] using equation (30)"""
        return 2 * (x - self.xmin.to(x.device)) / self.range.to(x.device) - 1

    def denorm(self, x):
        """Denormalize using equation (31)"""
        return ((x + 1) / 2) * self.range.to(x.device) + self.xmin.to(x.device)

    def scale_gradient(self, grad):
        """Scale gradient according to equation (32)"""
        return grad * 2 / self.range.to(grad.device)

def make_beta_schedule(T, beta_start=1e-4, beta_end=0.02, schedule='linear'):
    """Create noise schedule as described in Section III-A"""
    if schedule == 'linear':
        betas = torch.linspace(beta_start, beta_end, T)
    elif schedule == 'cosine':
        # Alternative cosine schedule
        s = 0.008
        steps = T + 1
        x = torch.linspace(0, T, steps)
        alphas_cumprod = torch.cos(((x / T) + s) / (1 + s) * torch.pi * 0.5) ** 2
        alphas_cumprod = alphas_cumprod / alphas_cumprod[0]
        betas = 1 - (alphas_cumprod[1:] / alphas_cumprod[:-1])
        betas = torch.clip(betas, beta_start, beta_end)

    alphas = 1.0 - betas
    alpha_bar = torch.cumprod(alphas, dim=0)
    return betas, alphas, alpha_bar

def power_flow_residual(x_phys, G, B):
    """
    Compute power flow residual based on Equations (8a) and (8b) from the paper.
    This is the correct formulation using power balance equations.
    """
    Bdim = G.shape[0]
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    batch_size = x_phys.shape[0]
    device = x_phys.device

    # Ensure G and B are tensors on the correct device
    if not isinstance(G, torch.Tensor):
        G = torch.tensor(G, dtype=torch.float32, device=device)
    if not isinstance(B, torch.Tensor):
        B = torch.tensor(B, dtype=torch.float32, device=device)

    # Expand dimensions for broadcasting
    v_i = v.unsqueeze(2)  # [batch, Bdim, 1]
    v_j = v.unsqueeze(1)  # [batch, 1, Bdim]
    theta_i = theta.unsqueeze(2)  # [batch, Bdim, 1]
    theta_j = theta.unsqueeze(1)  # [batch, 1, Bdim]

    # Calculate angle differences
    theta_diff = theta_i - theta_j  # [batch, Bdim, Bdim]

    # Power flow equations from the paper
    # P_i = Σ_j v_i * v_j * (G_ij * cos(θ_i - θ_j) + B_ij * sin(θ_i - θ_j))
    P_calc = torch.sum(v_i * v_j * (G * torch.cos(theta_diff) + B * torch.sin(theta_diff)), dim=2)

    # Q_i = Σ_j v_i * v_j * (G_ij * sin(θ_i - θ_j) - B_ij * cos(θ_i - θ_j))
    Q_calc = torch.sum(v_i * v_j * (G * torch.sin(theta_diff) - B * torch.cos(theta_diff)), dim=2)

    # Residuals (power balance mismatch)
    p_residual = p - P_calc
    q_residual = q - Q_calc

    return torch.cat([p_residual, q_residual], dim=-1)

def compute_inequality_violations(x_phys, net):
    """Compute violations of inequality constraints (10a-10d)"""
    Bdim = len(net.bus)
    p, q = x_phys[:, :Bdim], x_phys[:, Bdim:2*Bdim]
    v, theta = x_phys[:, 2*Bdim:3*Bdim], x_phys[:, 3*Bdim:4*Bdim]

    violations = []

    # Voltage limits (10c)
    v_min = torch.tensor(net.bus.min_vm_pu.values, device=x_phys.device)
    v_max = torch.tensor(net.bus.max_vm_pu.values, device=x_phys.device)
    violations.append(torch.relu(v_min - v))  # v >= v_min
    violations.append(torch.relu(v - v_max))  # v <= v_max

    return torch.cat(violations, dim=-1)

def make_dataset(net_fn, N=500, scale_range=(0.8, 1.0), seed=0):
    """Generate ground truth dataset by solving AC-OPF as described in Section VI-A"""
    np.random.seed(seed)
    torch.manual_seed(seed)

    net = net_fn()
    base_loads_p = net.load["p_mw"].copy()
    base_loads_q = net.load["q_mvar"].copy()

    samples = []
    print(f"Generating {N} samples...")

    pbar = tqdm(range(N), desc="Generating Data")
    for _ in pbar:
        net_temp = copy.deepcopy(net)

        # Sample load scaling factors uniformly as in the paper
        scale_p = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))
        scale_q = np.random.uniform(scale_range[0], scale_range[1], size=len(net.load))

        net_temp.load["p_mw"] = base_loads_p * scale_p
        net_temp.load["q_mvar"] = base_loads_q * scale_q

        try:
            # Run power flow (not OPF for simplicity in this implementation)
            pp.runpp(net_temp, algorithm='nr', init='dc', numba=False, max_iteration=50)

            if net_temp.converged:
                # Extract power injections and voltages
                p = net_temp.res_bus.p_mw.values
                q = net_temp.res_bus.q_mvar.values
                v = net_temp.res_bus.vm_pu.values
                theta = np.deg2rad(net_temp.res_bus.va_degree.values)

                # Stack into single vector
                sample = np.concatenate([p, q, v, theta])
                samples.append(sample)
                pbar.set_postfix({"collected": len(samples)})

        except Exception as e:
            continue

    print(f"Successfully generated {len(samples)} samples.")
    return torch.tensor(np.array(samples), dtype=torch.float32)

def train_model(data, B, config):
    """Train diffusion model with variable decoupling (Algorithm 4)"""
    device = config["device"]
    T = config["diffusion_steps"]

    # Create noise schedule
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Initialize denoiser networks for variable decoupling
    den1 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*B, config["hidden_dim"], config["depth"]).to(device)

    # Normalization
    data_min = data.min(0).values
    data_max = data.max(0).values

    # Add small noise to constant columns
    data_range = data_max - data_min
    constant_mask = data_range < 1e-6
    if constant_mask.any():
        print(f"Warning: Found {constant_mask.sum().item()} constant columns. Adding small noise.")
        data_min[constant_mask] -= 1e-4
        data_max[constant_mask] += 1e-4

    normer = MinMaxNorm(data_min, data_max)
    data_norm = normer.norm(data)

    # Check for NaN/Inf
    if torch.isnan(data_norm).any() or torch.isinf(data_norm).any():
        print("ERROR: NaN or Inf detected after normalization!")
        return None, None, None, None

    # Create dataloader
    loader = DataLoader(TensorDataset(data_norm), batch_size=config["batch_size"], shuffle=True)

    # Optimizer
    opt = torch.optim.AdamW(
        list(den1.parameters()) + list(den2.parameters()),
        lr=config["lr"],
        weight_decay=1e-5
    )

    # Learning rate scheduler
    scheduler = torch.optim.lr_scheduler.CosineAnnealingLR(opt, T_max=config["epochs"])

    loss_history = []

    print("Starting training...")
    for ep in range(config["epochs"]):
        total_loss = 0
        num_batches = 0

        pbar = tqdm(loader, desc=f"Epoch {ep+1}/{config['epochs']}")

        for (xb,) in pbar:
            xb = xb.to(device)

            # Variable decoupling: split into (p,θ) and (q,v)
            x1 = torch.cat([xb[:, :B], xb[:, 3*B:4*B]], dim=-1)  # (p, θ)
            x2 = torch.cat([xb[:, B:2*B], xb[:, 2*B:3*B]], dim=-1)  # (q, v)

            # Sample random timesteps
            t = torch.randint(0, T, (xb.size(0),), device=device)

            # Sample noise
            eps1 = torch.randn_like(x1)
            eps2 = torch.randn_like(x2)

            # Forward diffusion (equation 3)
            sqrt_ab_t = torch.sqrt(alpha_bar[t]).unsqueeze(-1)
            sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t]).unsqueeze(-1)

            x1_t = sqrt_ab_t * x1 + sqrt_1_minus_ab_t * eps1
            x2_t = sqrt_ab_t * x2 + sqrt_1_minus_ab_t * eps2

            # Predict noise
            pred1 = den1(x1_t, t)
            pred2 = den2(x2_t, t)

            # MSE loss (equation 5)
            loss1 = ((eps1 - pred1)**2).mean()
            loss2 = ((eps2 - pred2)**2).mean()
            loss = loss1 + loss2

            # Check for NaN
            if torch.isnan(loss):
                print(f"\nNaN loss detected at epoch {ep+1}!")
                break

            opt.zero_grad()
            loss.backward()

            # Gradient clipping for stability
            torch.nn.utils.clip_grad_norm_(
                list(den1.parameters()) + list(den2.parameters()),
                max_norm=1.0
            )

            opt.step()

            total_loss += loss.item()
            num_batches += 1
            pbar.set_postfix(loss=f"{loss.item():.4f}")

        scheduler.step()

        avg_loss = total_loss / num_batches
        loss_history.append(avg_loss)
        print(f"Epoch {ep+1} - Average Loss: {avg_loss:.4f}, LR: {scheduler.get_last_lr()[0]:.6f}")

    # Save checkpoint
    checkpoint = {
        "den1": den1.state_dict(),
        "den2": den2.state_dict(),
        "xmin": normer.xmin,
        "xmax": normer.xmax,
        "range": normer.range,
        "B": B
    }
    torch.save(checkpoint, "checkpoint.pth")
    print("Model saved to checkpoint.pth")

    return den1, den2, normer, loss_history

def sample_with_guidance(G, Bmat, config, ckpt_path="checkpoint.pth", track_residuals=False):
    """Sampling with manifold-constrained gradient guidance (Algorithm 5)"""
    device = config["device"]

    # Load checkpoint
    ckpt = torch.load(ckpt_path, map_location=device)
    Bdim = ckpt["B"]

    # Initialize denoisers
    den1 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den2 = DenoiserMLP(2*Bdim, config["hidden_dim"], config["depth"]).to(device)
    den1.load_state_dict(ckpt["den1"])
    den2.load_state_dict(ckpt["den2"])
    den1.eval()
    den2.eval()

    # Normalizer
    normer = MinMaxNorm(ckpt["xmin"], ckpt["xmax"])
    if "range" in ckpt:
        normer.range = ckpt["range"]

    # Noise schedule
    T = config["diffusion_steps"]
    betas, alphas, alpha_bar = make_beta_schedule(T, config["beta_start"], config["beta_end"])
    betas = betas.to(device)
    alphas = alphas.to(device)
    alpha_bar = alpha_bar.to(device)

    # Guidance strength
    lam = config["lambda_guidance"]

    # Initialize from pure noise
    x_t = torch.randn(1, 4 * Bdim, device=device)

    # Track residuals if requested
    residual_history = [] if track_residuals else None

    print("Starting guided sampling..." if track_residuals else "Sampling...")
    pbar = tqdm(reversed(range(T)), desc="Sampling", total=T, disable=not track_residuals)

    for t in pbar:
        # Split for variable decoupling
        x1_t = torch.cat([x_t[:, :Bdim], x_t[:, 3*Bdim:4*Bdim]], dim=-1)  # (p, θ)
        x2_t = torch.cat([x_t[:, Bdim:2*Bdim], x_t[:, 2*Bdim:3*Bdim]], dim=-1)  # (q, v)

        with torch.no_grad():
            t_tensor = torch.tensor([t], device=device)

            # Predict noise (denoisers)
            eps1 = den1(x1_t, t_tensor)
            eps2 = den2(x2_t, t_tensor)

        # Estimate clean data using Tweedie's formula (equation 6)
        sqrt_ab_t = torch.sqrt(alpha_bar[t])
        sqrt_1_minus_ab_t = torch.sqrt(1 - alpha_bar[t])

        hat_x0_p1 = (x1_t - sqrt_1_minus_ab_t * eps1) / (sqrt_ab_t + 1e-8)
        hat_x0_p2 = (x2_t - sqrt_1_minus_ab_t * eps2) / (sqrt_ab_t + 1e-8)

        # Reconstruct full vector
        hat_x0_norm = torch.zeros(1, 4*Bdim, device=device)
        hat_x0_norm[:, :Bdim] = hat_x0_p1[:, :Bdim]  # p
        hat_x0_norm[:, Bdim:2*Bdim] = hat_x0_p2[:, :Bdim]  # q
        hat_x0_norm[:, 2*Bdim:3*Bdim] = hat_x0_p2[:, Bdim:2*Bdim]  # v
        hat_x0_norm[:, 3*Bdim:4*Bdim] = hat_x0_p1[:, Bdim:2*Bdim]  # θ

        # Clamp for stability
        hat_x0_norm = torch.clamp(hat_x0_norm, -3, 3)

        # Apply gradient guidance if lambda > 0
        if lam > 0 and t > 0:  # No guidance at t=0
            hat_x0_norm.requires_grad_(True)

            # Denormalize for physics evaluation
            x_phys = normer.denorm(hat_x0_norm)

            # Compute power flow residual
            residual = power_flow_residual(x_phys, G, Bmat)
            residual_loss = (residual**2).sum()

            if track_residuals:
                residual_history.append(torch.sqrt(residual_loss).item())

            if not torch.isnan(residual_loss):
                # Compute gradient with respect to normalized variables
                grad_norm = torch.autograd.grad(residual_loss, hat_x0_norm, create_graph=False)[0]

                # Scale gradient properly
                grad_norm = normer.scale_gradient(grad_norm)

                # Clip gradient for stability
                grad_norm = torch.clamp(grad_norm, -1.0, 1.0)

                # Apply guidance (equation 23)
                guidance_strength = lam * (1 - t/T)  # Decay guidance over time
                hat_x0_guided = hat_x0_norm - guidance_strength * grad_norm
                hat_x0_guided = hat_x0_guided.detach()
            else:
                hat_x0_guided = hat_x0_norm.detach()
        else:
            hat_x0_guided = hat_x0_norm.detach()

        # Split guided estimate for variable decoupling
        hat_x0_guided_p1 = torch.cat([hat_x0_guided[:, :Bdim], hat_x0_guided[:, 3*Bdim:4*Bdim]], dim=-1)
        hat_x0_guided_p2 = torch.cat([hat_x0_guided[:, Bdim:2*Bdim], hat_x0_guided[:, 2*Bdim:3*Bdim]], dim=-1)

        # Reverse diffusion step (equation 7)
        if t > 0:
            z = torch.randn_like(x_t)
            z1 = torch.cat([z[:, :Bdim], z[:, 3*Bdim:4*Bdim]], dim=-1)
            z2 = torch.cat([z[:, Bdim:2*Bdim], z[:, 2*Bdim:3*Bdim]], dim=-1)
        else:
            z1 = z2 = 0

        beta_t = betas[t]
        alpha_t = alphas[t]
        alpha_bar_prev = alpha_bar[t-1] if t > 0 else torch.tensor(1.0, device=device)

        # DDPM sampling coefficients
        coef1 = torch.sqrt(alpha_bar_prev) * beta_t / (1 - alpha_bar[t] + 1e-8)
        coef2 = torch.sqrt(alpha_t) * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8)
        sigma_t = torch.sqrt(beta_t * (1 - alpha_bar_prev) / (1 - alpha_bar[t] + 1e-8))  # Fixed by adding closing parenthesis

        # Update x1_t and x2_t
        x1_t = coef1 * hat_x0_guided_p1 + coef2 * x1_t + sigma_t * z1
        x2_t = coef1 * hat_x0_guided_p2 + coef2 * x2_t + sigma_t * z2

        # Reconstruct full x_t
        x_t[:, :Bdim] = x1_t[:, :Bdim]
        x_t[:, Bdim:2*Bdim] = x2_t[:, :Bdim]
        x_t[:, 2*Bdim:3*Bdim] = x2_t[:, Bdim:2*Bdim]
        x_t[:, 3*Bdim:4*Bdim] = x1_t[:, Bdim:2*Bdim]

    # Final denormalization
    final_sample = normer.denorm(x_t).cpu().numpy()

    if track_residuals:
        return final_sample, residual_history
    return final_sample
def compute_wasserstein_distance_multidim(data1, data2, seed=None):
    """ Compute multidimensional 1-Wasserstein distance (W1) between two datasets using L2 cost, as in Equation (33) of the paper.
    Assumes equal sample sizes; subsample if needed. """
    # Check dimensionality compatibility
    if data1.shape[1] != data2.shape[1]:
        raise ValueError("Data dimensions must match")

    # Subsample to min size if unequal, with optional seed for reproducibility
    min_size = min(data1.shape[0], data2.shape[0])
    if seed is not None:
        np.random.seed(seed)
    if data1.shape[0] > min_size:
        data1 = data1[np.random.choice(data1.shape[0], min_size, replace=False)]
    if data2.shape[0] > min_size:
        data2 = data2[np.random.choice(data2.shape[0], min_size, replace=False)]

    # Compute L2 cost matrix: C_ij = ||data1[i] - data2[j]||_2
    cost_matrix = euclidean_distances(data1, data2)

    # Solve optimal assignment (Hungarian algorithm)
    row_ind, col_ind = linear_sum_assignment(cost_matrix)

    # W1 = (1 / N) * sum of assigned costs
    w1_distance = cost_matrix[row_ind, col_ind].sum() / min_size

    return w1_distance

# 5. Main Execution with Verification
if __name__ == "__main__":
    torch.manual_seed(CONFIG['seed'])
    np.random.seed(CONFIG['seed'])

    # Load network
    network_function = getattr(pn, CONFIG['system'])
    net = network_function()
    num_buses = len(net.bus)
    print(f"Using {CONFIG['system']} with {num_buses} buses")

    # Get admittance matrix
    pp.runpp(net)
    Ybus = net._ppc['internal']['Ybus']
    G_matrix, B_matrix = Ybus.real.toarray(), Ybus.imag.toarray()

    # Generate ground truth dataset
    dataset = make_dataset(network_function, N=CONFIG['num_samples'], seed=CONFIG['seed'])

    if len(dataset) > 0:
        print(f"\nDataset shape: {dataset.shape}")
        print(f"Dataset stats:")
        print(f"  P range: [{dataset[:, :num_buses].min():.2f}, {dataset[:, :num_buses].max():.2f}] MW")
        print(f"  Q range: [{dataset[:, num_buses:2*num_buses].min():.2f}, {dataset[:, num_buses:2*num_buses].max():.2f}] MVAr")
        print(f"  V range: [{dataset[:, 2*num_buses:3*num_buses].min():.3f}, {dataset[:, 2*num_buses:3*num_buses].max():.3f}] p.u.")
        print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")

        # Check ground truth feasibility
        print("\nChecking ground truth feasibility...")
        gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
        gt_residuals = power_flow_residual(gt_tensor, G_matrix, B_matrix)
        gt_mismatch = torch.sqrt((gt_residuals**2).mean(dim=1))
        print(f"Ground truth power mismatch (first 10): {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

        # Train the diffusion model
        den1, den2, normer, loss_history = train_model(dataset, num_buses, CONFIG)

        if den1 is not None:
            # Plot training loss
            plt.figure(figsize=(6, 4))
            plt.plot(range(1, len(loss_history) + 1), loss_history, linewidth=2)
            plt.xlabel("Epoch")
            plt.ylabel("Average Loss")
            plt.title("Training Loss over Epochs")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # Generate synthetic samples
            print(f"\nGenerating {CONFIG['num_synthetic_samples']} synthetic samples...")
            synthetic_samples = []

            # First sample with residual tracking
            first_sample, residual_history = sample_with_guidance(
                G_matrix, B_matrix, CONFIG, track_residuals=True
            )
            synthetic_samples.append(first_sample[0])

            # Generate remaining samples
            for i in tqdm(range(1, CONFIG['num_synthetic_samples']), desc="Generating samples"):
                sample = sample_with_guidance(G_matrix, B_matrix, CONFIG, track_residuals=False)
                synthetic_samples.append(sample[0])

            synthetic_data = np.array(synthetic_samples)
            ground_truth_data = dataset.numpy()

            # Verification Results
            print("\n" + "="*60)
            print("VERIFICATION RESULTS (As per Table I and II in the paper)")
            print("="*60)

            # 1. Wasserstein Distance (Table I)
            print("\n1. Statistical Similarity (Wasserstein Distance):")
            subset_size = min(1000, len(ground_truth_data), len(synthetic_data))
            w_distance = compute_wasserstein_distance_multidim(
                ground_truth_data[:subset_size],
                synthetic_data[:subset_size]
            )
            print(f"   Wasserstein distance: {w_distance:.4f}")

            # ==============================================================
            # 2. Constraint Satisfaction (Section VI-C)
            # ==============================================================
            print("\n2. Constraint Satisfaction (Power Flow Residuals):")
            synth_tensor = torch.tensor(synthetic_data, dtype=torch.float32)
            synth_residuals = power_flow_residual(synth_tensor, G_matrix, B_matrix)
            synth_mismatch = torch.sqrt((synth_residuals ** 2).mean(dim=1))
            print(f"   Synthetic mean mismatch: {synth_mismatch.mean():.6f} ± {synth_mismatch.std():.6f}")
            print(f"   Ground truth mean mismatch: {gt_mismatch.mean():.6f} ± {gt_mismatch.std():.6f}")

            # Plot residual convergence history
            plt.figure(figsize=(6, 4))
            plt.plot(residual_history, linewidth=2)
            plt.xlabel("Diffusion step (t)")
            plt.ylabel("Residual norm ||H(x)||₂")
            plt.title("Residual Convergence During Guided Sampling")
            plt.grid(True, alpha=0.4)
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 3. Visual Comparison (Section VI-B figures)
            # ==============================================================
            print("\n3. Visualizing statistical similarity...")

            var_names = ['P (MW)', 'Q (MVAr)', 'V (p.u.)', 'θ (rad)']
            num_buses = G_matrix.shape[0]
            fig, axs = plt.subplots(4, 1, figsize=(8, 10))
            for i in range(4):
                start = i * num_buses
                end = (i + 1) * num_buses
                sns.kdeplot(dataset[:, start:end].flatten(), label="Ground Truth", ax=axs[i])
                sns.kdeplot(synthetic_data[:, start:end].flatten(), label="Synthetic", ax=axs[i])
                axs[i].set_title(var_names[i])
                axs[i].legend()
            plt.tight_layout()
            plt.show()

            # Additional plots for P, Q, V, θ for five randomly selected buses
            print("   Creating bus-level distribution plots for five buses...")
            np.random.seed(CONFIG['seed'])  # Ensure reproducibility
            selected_buses = np.random.choice(num_buses, 5, replace=False)
            fig, axs = plt.subplots(5, 4, figsize=(16, 12), sharex='col')
            for row, bus_idx in enumerate(selected_buses):
                # Plot P, Q, V, θ for each selected bus
                for col, (var_name, offset) in enumerate(zip(var_names, [0, num_buses, 2*num_buses, 3*num_buses])):
                    idx = offset + bus_idx
                    sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
                    sns.kdeplot(synthetic_data[:, idx], label="Synthetic", ax=axs[row, col])
                    if row == 0:
                        axs[row, col].set_title(f"{var_name}")
                    if col == 0:
                        axs[row, col].set_ylabel(f"Bus {bus_idx}")
                    if row == 4:
                        axs[row, col].set_xlabel(var_name.split(' ')[0])
                    axs[row, col].legend()
            plt.suptitle("Bus-Level Distributions for P, Q, V, θ", fontsize=16)
            plt.tight_layout(rect=[0, 0, 1, 0.95])
            plt.show()

            # Joint scatter plots like in the image for 5 random buses
            print("   Creating joint density plots for 5 random buses...")
            base_kv = net.bus.vn_kv.values  # Base voltages for each bus
            np.random.seed(CONFIG['seed'])  # Ensure reproducibility
            selected_buses = np.random.choice(num_buses, 5, replace=False)
            fig, axs = plt.subplots(2, 5, figsize=(15, 6), sharey='row')
            for col, bus in enumerate(selected_buses):
                # Top row: q vs p (MVAr vs MW)
                sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
                            fill=True, cmap="Blues", alpha=0.5, ax=axs[0, col])
                sns.scatterplot(x=synthetic_data[:, bus], y=synthetic_data[:, num_buses + bus],
                                color="magenta", alpha=0.3, label="Syn.: constrained", ax=axs[0, col])
                axs[0, col].set_xlabel(f"p_{bus+1} (MW)")
                if col == 0:
                    axs[0, col].set_ylabel("q (MVAr)")
                axs[0, col].legend(loc='upper left')

                # Bottom row: theta (rad) vs v (kV)
                v_gt_kv = ground_truth_data[:, 2*num_buses + bus] * base_kv[bus]
                theta_gt = ground_truth_data[:, 3*num_buses + bus]
                v_syn_kv = synthetic_data[:, 2*num_buses + bus] * base_kv[bus]
                theta_syn = synthetic_data[:, 3*num_buses + bus]
                sns.kdeplot(x=v_gt_kv, y=theta_gt,
                            fill=True, cmap="Blues", alpha=0.5, ax=axs[1, col])
                sns.scatterplot(x=v_syn_kv, y=theta_syn,
                                color="magenta", alpha=0.3, label="Syn.: constrained", ax=axs[1, col])
                axs[1, col].set_xlabel(f"v_{bus+1} (kV)")
                if col == 0:
                    axs[1, col].set_ylabel("θ (rad)")
                axs[1, col].legend(loc='upper left')

            # Add colorbar for density
            fig.subplots_adjust(right=0.85)
            cbar_ax = fig.add_axes([0.88, 0.15, 0.02, 0.7])
            plt.colorbar(axs[0,0].collections[0], cax=cbar_ax, label="Density Estimate")
            plt.tight_layout(rect=[0, 0, 0.85, 1])
            plt.show()

            # Joint scatter plots (P vs Q, V vs θ)
            print("   Creating joint density plots...")
            plt.figure(figsize=(10, 4))
            plt.subplot(1, 2, 1)
            sns.kdeplot(
                x=dataset[:, 0], y=dataset[:, num_buses],
                fill=True, cmap="Blues", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 0], y=synthetic_data[:, num_buses],
                color="red", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: P vs Q")

            plt.subplot(1, 2, 2)
            sns.kdeplot(
                x=dataset[:, 2*num_buses], y=dataset[:, 3*num_buses],
                fill=True, cmap="Greens", label="Ground Truth", alpha=0.5
            )
            sns.scatterplot(
                x=synthetic_data[:, 2*num_buses], y=synthetic_data[:, 3*num_buses],
                color="purple", alpha=0.3, label="Synthetic"
            )
            plt.title("Joint Distribution: V vs θ")
            plt.tight_layout()
            plt.show()

            # ==============================================================
            # 4. Utility in Downstream ML Task (Section VI-D)
            # ==============================================================
            print("\n4. Downstream ML Task: Warm-Start Prediction Test")

            import sklearn.model_selection as skms
            import sklearn.neural_network as sknn
            from sklearn.metrics import mean_squared_error

            # Create simple supervised learning task
            # Here we try to learn mapping from (p,q) → (v,θ)
            X_gt = dataset[:, :2*num_buses].numpy()
            y_gt = dataset[:, 2*num_buses:].numpy()

            X_syn = synthetic_data[:, :2*num_buses]
            y_syn = synthetic_data[:, 2*num_buses:]

            # Train-test split
            X_train_gt, X_test_gt, y_train_gt, y_test_gt = skms.train_test_split(X_gt, y_gt, test_size=0.3, random_state=CONFIG['seed'])
            X_train_syn, X_test_syn, y_train_syn, y_test_syn = skms.train_test_split(X_syn, y_syn, test_size=0.3, random_state=CONFIG['seed'])

            # MLP regressor
            def train_mlp(X_train, y_train):
                mlp = sknn.MLPRegressor(hidden_layer_sizes=(128, 128),
                                         activation='relu',
                                         solver='adam',
                                         max_iter=500,
                                         random_state=CONFIG['seed'])
                mlp.fit(X_train, y_train)
                return mlp

            print("   Training baseline (Ground Truth)...")
            mlp_gt = train_mlp(X_train_gt, y_train_gt)
            print("   Training on constrained synthetic data...")
            mlp_syn = train_mlp(X_train_syn, y_train_syn)

            # Evaluate
            y_pred_gt = mlp_gt.predict(X_test_gt)
            y_pred_syn = mlp_syn.predict(X_test_gt)

            mse_gt = mean_squared_error(y_test_gt, y_pred_gt)
            mse_syn = mean_squared_error(y_test_gt, y_pred_syn)

            print(f"   MSE using Ground Truth: {mse_gt:.6f}")
            print(f"   MSE using Synthetic Data: {mse_syn:.6f}")
            print("\n===========================================================")
            print("EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY")
            print("===========================================================")

        else:
            print("Dataset generation failed or returned no samples.")
    else:
        print("Dataset generation failed. Check pandapower installation or seed.")
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 25.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.4/91.4 kB 4.1 MB/s eta 0:00:00
# Using case30 with 30 buses
# Generating 5000 samples...
# Generating Data: 100%|██████████| 5000/5000 [04:49<00:00, 17.28it/s, collected=5000]
# /tmp/ipython-input-2294299372.py:544: DeprecationWarning: __array_wrap__ must accept context and return_scalar arguments (positionally) in the future. (Deprecated NumPy 2.0)
#   print(f"  θ range: [{np.rad2deg(dataset[:, 3*num_buses:].min()):.1f}, {np.rad2deg(dataset[:, 3*num_buses:].max()):.1f}] degrees")
# /tmp/ipython-input-2294299372.py:548: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   gt_tensor = torch.tensor(dataset[:10], dtype=torch.float32)
# Successfully generated 5000 samples.
#
# Dataset shape: torch.Size([5000, 120])
# Dataset stats:
#   P range: [-43.61, 30.00] MW
#   Q range: [-37.86, 30.00] MVAr
#   V range: [0.962, 1.000] p.u.
#   θ range: [-3.2, 3.7] degrees
#
# Checking ground truth feasibility...
# Ground truth power mismatch (first 10): 12.508062 ± 0.106577
# Warning: Found 21 constant columns. Adding small noise.
# Starting training...
# Epoch 1/500: 100%|██████████| 79/79 [00:01<00:00, 59.85it/s, loss=2.0961]
# Epoch 1 - Average Loss: 3.1007, LR: 0.000100
# Epoch 371/500: 100%|██████████| 79/79 [00:01<00:00, 54.44it/s, loss=0.2196]
# Epoch 371 - Average Loss: 0.1667, LR: 0.000016
# Epoch 372/500: 100%|██████████| 79/79 [00:01<00:00, 56.01it/s, loss=0.0978]
# Epoch 372 - Average Loss: 0.1657, LR: 0.000015
# Epoch 373/500: 100%|██████████| 79/79 [00:01<00:00, 53.12it/s, loss=0.1871]
# Epoch 373 - Average Loss: 0.1650, LR: 0.000015
# Epoch 374/500: 100%|██████████| 79/79 [00:01<00:00, 50.39it/s, loss=0.0653]
# Epoch 374 - Average Loss: 0.1672, LR: 0.000015
# Epoch 375/500: 100%|██████████| 79/79 [00:01<00:00, 43.72it/s, loss=0.1512]
# Epoch 375 - Average Loss: 0.1631, LR: 0.000015
# Epoch 376/500: 100%|██████████| 79/79 [00:01<00:00, 42.51it/s, loss=0.2268]
# Epoch 376 - Average Loss: 0.1565, LR: 0.000014
# Epoch 377/500: 100%|██████████| 79/79 [00:01<00:00, 54.54it/s, loss=0.1743]
# Epoch 377 - Average Loss: 0.1584, LR: 0.000014
# Epoch 378/500: 100%|██████████| 79/79 [00:01<00:00, 53.74it/s, loss=0.3556]
# Epoch 378 - Average Loss: 0.1675, LR: 0.000014
# Epoch 379/500: 100%|██████████| 79/79 [00:01<00:00, 52.76it/s, loss=0.3019]
# Epoch 379 - Average Loss: 0.1530, LR: 0.000014
# Epoch 380/500: 100%|██████████| 79/79 [00:01<00:00, 54.60it/s, loss=0.2040]
# Epoch 380 - Average Loss: 0.1629, LR: 0.000014
# Epoch 381/500: 100%|██████████| 79/79 [00:01<00:00, 52.61it/s, loss=0.1312]
# Epoch 381 - Average Loss: 0.1590, LR: 0.000013
# ...
# Sampling...
# Generating samples:  68%|██████▊   | 339/499 [15:01<06:54,  2.59s/it]
# Sampling...
# Generating samples:  68%|██████▊   | 340/499 [15:04<06:47,  2.56s/it]
# Sampling...
# Generating samples:  68%|██████▊   | 341/499 [15:07<07:01,  2.67s/it]
# Sampling...
# Generating samples:  69%|██████▊   | 342/499 [15:09<07:05,  2.71s/it]
# Sampling...
# Generating samples:  69%|██████▊   | 343/499 [15:12<06:48,  2.62s/it]
# Sampling...
# Generating samples:  69%|██████▉   | 344/499 [15:14<06:38,  2.57s/it]
# Sampling...
# Generating samples:  69%|██████▉   | 345/499 [15:17<06:30,  2.54s/it]
# Sampling...
# Generating samples:  69%|██████▉   | 346/499 [15:20<07:04,  2.77s/it]
# Sampling...
# Generating samples:  70%|██████▉   | 347/499 [15:23<06:52,  2.72s/it]
# Sampling...
# Generating samples:  70%|██████▉   | 348/499 [15:25<06:45,  2.69s/it]
# Sampling...
# Generating samples:  70%|██████▉   | 349/499 [15:28<06:36,  2.64s/it]
# Sampling...
# Generating samples:  70%|███████   | 350/499 [15:31<06:38,  2.67s/it]
# Sampling...
# Generating samples:  70%|███████   | 351/499 [15:34<06:51,  2.78s/it]
# Sampling...
# Generating samples:  71%|███████   | 352/499 [15:36<06:35,  2.69s/it]
# Sampling...
# Generating samples:  77%|███████▋  | 386/499 [17:07<04:53,  2.59s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 387/499 [17:10<05:02,  2.71s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 388/499 [17:13<05:03,  2.73s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 389/499 [17:15<04:52,  2.66s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 390/499 [17:18<04:45,  2.62s/it]
# Sampling...
# Generating samples:  78%|███████▊  | 391/499 [17:20<04:37,  2.57s/it]
# Sampling...
# Generating samples:  79%|███████▊  | 392/499 [17:23<04:55,  2.76s/it]
# Sampling...
# Generating samples:  79%|███████▉  | 393/499 [17:26<04:42,  2.66s/it]
# Sampling...
# Generating samples:  79%|███████▉  | 394/499 [17:28<04:34,  2.61s/it]
# Sampling...
# Generating samples:  79%|███████▉  | 395/499 [17:31<04:26,  2.56s/it]
# Sampling...
# Generating samples:  79%|███████▉  | 396/499 [17:33<04:27,  2.60s/it]
# Sampling...
# Generating samples:  80%|███████▉  | 397/499 [17:37<04:44,  2.79s/it]
# Sampling...
# Generating samples:  80%|███████▉  | 398/499 [17:39<04:35,  2.73s/it]
# Sampling...
# Generating samples:  80%|███████▉  | 399/499 [17:42<04:25,  2.65s/it]
# Sampling...
# Generating samples:  80%|████████  | 400/499 [17:44<04:17,  2.61s/it]
# Sampling...
# Generating samples:  80%|████████  | 401/499 [17:47<04:33,  2.79s/it]
# Sampling...
# Generating samples:  81%|████████  | 402/499 [17:50<04:32,  2.81s/it]
# Sampling...
# Generating samples:  81%|████████  | 403/499 [17:53<04:23,  2.74s/it]
# Sampling...
# Generating samples:  81%|████████  | 404/499 [17:55<04:11,  2.64s/it]
# Sampling...
# Generating samples:  81%|████████  | 405/499 [17:58<04:03,  2.59s/it]
# Sampling...
# Generating samples:  81%|████████▏ | 406/499 [18:01<04:18,  2.78s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 407/499 [18:03<04:08,  2.70s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 408/499 [18:06<04:00,  2.64s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 409/499 [18:08<03:52,  2.58s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 410/499 [18:11<03:56,  2.66s/it]
# Sampling...
# Generating samples:  82%|████████▏ | 411/499 [18:14<03:59,  2.73s/it]
# Sampling...
# Generating samples:  83%|████████▎ | 412/499 [18:16<03:48,  2.62s/it]
# Sampling...
# Generating samples:  83%|████████▎ | 413/499 [18:19<03:41,  2.58s/it]
# Sampling...
# Generating samples:  83%|████████▎ | 414/499 [18:21<03:35,  2.54s/it]
# Sampling...
# Generating samples:  83%|████████▎ | 415/499 [18:25<03:51,  2.75s/it]
# Sampling...
# Generating samples:  83%|████████▎ | 416/499 [18:27<03:41,  2.67s/it]
# Sampling...
# Generating samples:  84%|████████▎ | 417/499 [18:30<03:33,  2.60s/it]
# Sampling...
# Generating samples:  84%|████████▍ | 418/499 [18:32<03:27,  2.56s/it]
# Sampling...
# Generating samples:  84%|████████▍ | 419/499 [18:34<03:21,  2.52s/it]
# Sampling...
# Generating samples:  84%|████████▍ | 420/499 [18:38<03:33,  2.70s/it]
# Sampling...
# Generating samples:  84%|████████▍ | 421/499 [18:40<03:24,  2.62s/it]
# Sampling...
# Generating samples:  85%|████████▍ | 422/499 [18:42<03:19,  2.58s/it]
# Sampling...
# Generating samples:  85%|████████▍ | 423/499 [18:45<03:16,  2.59s/it]
# Sampling...
# Generating samples:  85%|████████▍ | 424/499 [18:48<03:17,  2.64s/it]
# Sampling...
# Generating samples:  85%|████████▌ | 425/499 [18:51<03:23,  2.75s/it]
# Sampling...
# Generating samples:  85%|████████▌ | 426/499 [18:53<03:15,  2.68s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 427/499 [18:56<03:08,  2.62s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 428/499 [18:58<03:01,  2.55s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 429/499 [19:01<03:11,  2.74s/it]
# Sampling...
# Generating samples:  86%|████████▌ | 430/499 [19:04<03:03,  2.66s/it]
# Sampling...
# Generating samples:  86%|████████▋ | 431/499 [19:06<02:56,  2.59s/it]
# Sampling...
# Generating samples:  87%|████████▋ | 432/499 [19:09<02:51,  2.55s/it]
# Sampling...
# Generating samples:  87%|████████▋ | 433/499 [19:11<02:46,  2.52s/it]
# Sampling...
# Generating samples:  87%|████████▋ | 434/499 [19:14<02:57,  2.73s/it]
# Sampling...
# Generating samples:  87%|████████▋ | 435/499 [19:17<02:52,  2.70s/it]
# Sampling...
# Generating samples:  87%|████████▋ | 436/499 [19:20<02:48,  2.68s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 437/499 [19:22<02:44,  2.66s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 438/499 [19:25<02:48,  2.76s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 439/499 [19:28<02:44,  2.75s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 440/499 [19:31<02:38,  2.69s/it]
# Sampling...
# Generating samples:  88%|████████▊ | 441/499 [19:33<02:33,  2.65s/it]
# Sampling...
# Generating samples:  89%|████████▊ | 442/499 [19:36<02:28,  2.61s/it]
# Sampling...
# Generating samples:  89%|████████▉ | 443/499 [19:39<02:35,  2.78s/it]
# Sampling...
# Generating samples:  89%|████████▉ | 444/499 [19:41<02:27,  2.68s/it]
# Sampling...
# Generating samples:  89%|████████▉ | 445/499 [19:44<02:23,  2.66s/it]
# Sampling...
# Generating samples:  89%|████████▉ | 446/499 [19:46<02:19,  2.63s/it]
# Sampling...
# Generating samples:  90%|████████▉ | 447/499 [19:49<02:17,  2.64s/it]
# Sampling...
# Generating samples:  90%|████████▉ | 448/499 [19:52<02:21,  2.77s/it]
# Sampling...
# Generating samples:  90%|████████▉ | 449/499 [19:55<02:14,  2.68s/it]
# Sampling...
# Generating samples:  90%|█████████ | 450/499 [19:57<02:10,  2.67s/it]
# Sampling...
# Generating samples:  90%|█████████ | 451/499 [20:00<02:05,  2.61s/it]
# Sampling...
# Generating samples:  91%|█████████ | 452/499 [20:03<02:10,  2.77s/it]
# Sampling...
# Generating samples:  91%|█████████ | 453/499 [20:05<02:02,  2.66s/it]
# Sampling...
# Generating samples:  91%|█████████ | 454/499 [20:08<01:56,  2.58s/it]
# Sampling...
# Generating samples:  91%|█████████ | 455/499 [20:10<01:51,  2.52s/it]
# Sampling...
# Generating samples:  91%|█████████▏| 456/499 [20:12<01:46,  2.47s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 457/499 [20:16<01:52,  2.69s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 458/499 [20:18<01:47,  2.61s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 459/499 [20:20<01:41,  2.54s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 460/499 [20:23<01:37,  2.50s/it]
# Sampling...
# Generating samples:  92%|█████████▏| 461/499 [20:25<01:36,  2.53s/it]
# Sampling...
# Generating samples:  93%|█████████▎| 462/499 [20:29<01:40,  2.71s/it]
# Sampling...
# Generating samples:  93%|█████████▎| 463/499 [20:31<01:34,  2.63s/it]
# Sampling...
# Generating samples:  93%|█████████▎| 464/499 [20:33<01:30,  2.58s/it]
# Sampling...
# Generating samples:  93%|█████████▎| 465/499 [20:36<01:25,  2.52s/it]
# Sampling...
# Generating samples:  93%|█████████▎| 466/499 [20:39<01:26,  2.61s/it]
# Sampling...
# Generating samples:  94%|█████████▎| 467/499 [20:41<01:25,  2.67s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 468/499 [20:44<01:20,  2.61s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 469/499 [20:46<01:17,  2.57s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 470/499 [20:49<01:13,  2.53s/it]
# Sampling...
# Generating samples:  94%|█████████▍| 471/499 [20:52<01:17,  2.77s/it]
# Sampling...
# Generating samples:  95%|█████████▍| 472/499 [20:55<01:12,  2.70s/it]
# Sampling...
# Generating samples:  95%|█████████▍| 473/499 [20:57<01:08,  2.62s/it]
# Sampling...
# Generating samples:  95%|█████████▍| 474/499 [21:00<01:04,  2.57s/it]
# Sampling...
# Generating samples:  95%|█████████▌| 475/499 [21:02<01:00,  2.53s/it]
# Sampling...
# Generating samples:  95%|█████████▌| 476/499 [21:05<01:02,  2.71s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 477/499 [21:08<00:57,  2.61s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 478/499 [21:10<00:53,  2.56s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 479/499 [21:12<00:50,  2.51s/it]
# Sampling...
# Generating samples:  96%|█████████▌| 480/499 [21:15<00:48,  2.57s/it]
# Sampling...
# Generating samples:  96%|█████████▋| 481/499 [21:18<00:48,  2.69s/it]
# Sampling...
# Generating samples:  97%|█████████▋| 482/499 [21:21<00:44,  2.62s/it]
# Sampling...
# Generating samples:  97%|█████████▋| 483/499 [21:23<00:40,  2.55s/it]
# Sampling...
# Generating samples:  97%|█████████▋| 484/499 [21:25<00:37,  2.51s/it]
# Sampling...
# Generating samples:  97%|█████████▋| 485/499 [21:28<00:37,  2.65s/it]
# Sampling...
# Generating samples:  97%|█████████▋| 486/499 [21:31<00:34,  2.64s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 487/499 [21:33<00:30,  2.57s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 488/499 [21:36<00:27,  2.52s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 489/499 [21:38<00:24,  2.49s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 490/499 [21:41<00:24,  2.70s/it]
# Sampling...
# Generating samples:  98%|█████████▊| 491/499 [21:44<00:20,  2.62s/it]
# Sampling...
# Generating samples:  99%|█████████▊| 492/499 [21:46<00:18,  2.58s/it]
# Sampling...
# Generating samples:  99%|█████████▉| 493/499 [21:49<00:15,  2.53s/it]
# Sampling...
# Generating samples:  99%|█████████▉| 494/499 [21:51<00:12,  2.50s/it]
# Sampling...
# Generating samples:  99%|█████████▉| 495/499 [21:54<00:10,  2.72s/it]
# Sampling...
# Generating samples:  99%|█████████▉| 496/499 [21:57<00:07,  2.64s/it]
# Sampling...
# Generating samples: 100%|█████████▉| 497/499 [21:59<00:05,  2.58s/it]
# Sampling...
# Generating samples: 100%|█████████▉| 498/499 [22:02<00:02,  2.53s/it]
# Sampling...
# Generating samples: 100%|██████████| 499/499 [22:04<00:00,  2.66s/it]
# ============================================================
# VERIFICATION RESULTS (As per Table I and II in the paper)
# ============================================================
#
# 1. Statistical Similarity (Wasserstein Distance):
#    Wasserstein distance: 3.5273
#
# 2. Constraint Satisfaction (Power Flow Residuals):
#    Synthetic mean mismatch: 12.517521 ± 0.166976
#    Ground truth mean mismatch: 12.508062 ± 0.106577
# 3. Visualizing statistical similarity...
#    Creating bus-level distribution plots for five buses...
# /tmp/ipython-input-2294299372.py:646: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-2294299372.py:646: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-2294299372.py:646: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
# /tmp/ipython-input-2294299372.py:646: UserWarning: Dataset has 0 variance; skipping density estimate. Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(dataset[:, idx].numpy(), label="Ground Truth", ax=axs[row, col])
#    Creating joint density plots for 5 random buses...
# /tmp/ipython-input-2294299372.py:667: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
# /tmp/ipython-input-2294299372.py:667: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(x=ground_truth_data[:, bus], y=ground_truth_data[:, num_buses + bus],
# /tmp/ipython-input-2294299372.py:694: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 0.85, 1])
#    Creating joint density plots...
# /tmp/ipython-input-2294299372.py:712: UserWarning: KDE cannot be estimated (0 variance or perfect covariance). Pass `warn_singular=False` to disable this warning.
#   sns.kdeplot(
# 4. Downstream ML Task: Warm-Start Prediction Test
#    Training baseline (Ground Truth)...
#    Training on constrained synthetic data...
#    MSE using Ground Truth: 0.005828
#    MSE using Synthetic Data: 0.016797
#
# ===========================================================
# EXPERIMENTAL VERIFICATION COMPLETED SUCCESSFULLY
# ===========================================================
